# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
# </style>
#
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111: Introduction to Databases<br>
# Spring 2023, Sections 002
# </span>
# </center></b>
# <br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# Homework 0: Environment Setup and Test<br>
# </span>
# </center></i>

# %% [markdown]
# # Introduction and Overview

# %% [markdown]
# ## HW Objectives

# %% [markdown]
# This section of W4111 - Intro. to Databases defines required and recommended SW tools. Students are busy and often defer tasks to "just before the homework is due." In previous semesters, students were struggling with SW installation right before the submission deadline. To avoid this problem, HW 0 tests the installation and configuration of the SW.
#
# The [specification](https://docs.google.com/document/d/1D_PSOpQHTkWpr9NTJKQIH2W29lHbRZCaZ5tbuYfP1rk/edit?usp=sharing) for HW 0 documents the installation and configuration tasks. If you cannot access the Google doc, there is a [PDF](https://github.com/donald-f-ferguson/S23-W4111-HW0/blob/main/S23-W4111-HW0-Setup.pdf) version in the HW 0 GitHub repository.

# %% [markdown]
# ## Submission Instructions

# %% [markdown]
# Complete all the tests in this notebook and submit only this notebook as a PDF to GradeScope. To convert the jupyter notebook into a pdf you can use either of the following methods:
#
# - File --> Print Preview --> Print --> Save to PDF
#
# - File --> Download As HTML --> Print --> Save to PDF
#
#
# __Due date: September 29, 11:59 PM EDT on GradeScope__
#
# Please note: You may NOT use late days for the submission of this assignment. Check Courseworks for GradeScope access.
#
#
# It is recommended that you put the screenshots into the same folder as this notebook so you do not have to alter the path to include your images.
#
#
# Please read all the instructions thoroughly!

# %% [markdown]
# ## Add Student Information
#
# 1. Replace my name with your full name.
# 2. Replace my UNI with your UNI.
# 3. Replace "Cool Track" with either "Programming" or "Non-programming."

# %%
# Print your name, uni, and track below

name = "Ziggy Chen"
uni = "xc2605"
track = "Programming"

print(name)
print(uni)
print(track)
# Out:
# Ziggy Chen
# xc2605
# Programming

# %% [markdown]
# ## Python Version
#
# The test below should return the path to the Python interpreter for your Anaconda environment. The exact path may be differ from Mac to Windows, or based on installation choices you made. As long as the path has "anacondaq3" in it, you should be OK.

# %%
import sys

# %%
ex = sys.executable
ex
# Out:
# '/Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/bin/python'

# %%
# Checking that anacoda3 is in the path.
#
if 'anaconda3' in ex:
    print("Test seems OK.")
else:
    print("Not cool.")
# Out:
# Test seems OK.

# %% [markdown]
# The following tests that you have a sufficiently up to date version of Python.

# %%
print("Python version information:", sys.version_info, "\n")
if sys.version_info.major != 3 or \
    ((sys.version_info.major == 3) and (sys.version_info.minor < 9)):
    print("You have an invalid version of Python.")
else:
    print("Your Python version is OK.")
# Out:
# Python version information: sys.version_info(major=3, minor=10, micro=10, releaselevel='final', serial=0)
#
# Your Python version is OK.

# %% [markdown]
# If the test fails, you have to install Anaconda properly.

# %% [markdown]
# ## Install ipython-sql

# %% [markdown]
# The actual message below will vary based on what you do/do not already have installed. You are fine as long as there is not a major error.

# %%
# %pip install ipython-sql==0.4.1
# Out:
# Requirement already satisfied: ipython-sql==0.4.1 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: prettytable<1 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython-sql==0.4.1) (0.7.2)
# Requirement already satisfied: six in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython-sql==0.4.1) (1.16.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython-sql==0.4.1) (1.4.46)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython-sql==0.4.1) (0.2.0)
# Requirement already satisfied: ipython>=1.0 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython-sql==0.4.1) (8.10.0)
# Requirement already satisfied: sqlparse in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython-sql==0.4.1) (0.4.3)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1) (3.0.36)
# Requirement already satisfied: pexpect>4.3 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.1.6)
# Requirement already satisfied: decorator in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1) (5.1.1)
# Requirement already satisfied: backcall in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.7.5)
# Requirement already satisfied: traitlets>=5 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1) (5.7.1)
# Requirement already satisfied: appnope in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.1.2)
# Requirement already satisfied: pygments>=2.4.0 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1) (2.11.2)
# Requirement already satisfied: stack-data in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from sqlalchemy>=0.6.7->ipython-sql==0.4.1) (2.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql==0.4.1) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql==0.4.1) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=1.0->ipython-sql==0.4.1) (0.2.5)
# Requirement already satisfied: pure-eval in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from stack-data->ipython>=1.0->ipython-sql==0.4.1) (0.2.2)
# Requirement already satisfied: executing in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from stack-data->ipython>=1.0->ipython-sql==0.4.1) (0.8.3)
# Requirement already satisfied: asttokens in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from stack-data->ipython>=1.0->ipython-sql==0.4.1) (2.0.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# - If you got errors, please follow the [instructions in the ipython-sql site](https://github.com/catherinedevlin/ipython-sql) to install the magic.
#
#
# - __NOTE:__ Running the cell above may produce multiple notifications about installing requirements or requirement already satisfied. That is normal.
#
#
#
# - Once you get the install to work without errors, run the following cell.

# %%
# %load_ext sql

# %% [markdown]
# - If you did not get an error response, your test passed.
#
#
# - If you run the cell twice, your answer should be:
#
# ```
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# ```

# %% [markdown]
# ## SQLAlchemy/PyMySQL

# %% [markdown]
# Install ```sqlalchemy``` and ```pymysql.``` These are Python language packages for interacting with SQL and MySQL databases. Your actual response message may be different. Your environment is OK if you do not get a major error.

# %%
# %pip install sqlalchemy==1.4.46
# %pip install pymysql==1.0.2
# %pip install pandas
# Out:
# Requirement already satisfied: sqlalchemy==1.4.46 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (1.4.46)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from sqlalchemy==1.4.46) (2.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pymysql==1.0.2 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (1.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from pandas) (2023.2)
# Requirement already satisfied: six>=1.5 in /Users/ziggyxchen/opt/anaconda3/envs/COMS4111-3-10/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ## MySQL Connectivity

# %% [markdown]
# You installed MySQL Community Edition. You have to choose a userID and password during the installation.
#
#
# Please set the values in the cell below.

# %%
# Replace root with the user ID for MySQL and dbuserdbuser with the password you set.
# %sql mysql+pymysql://root:dbuserdbuser@localhost

# %%
# Another test
# %sql select * from db_book.student
# Out:
#  * mysql+pymysql://root:***@localhost
# 13 rows affected.
# [('00128', 'Zhang', 'Comp. Sci.', Decimal('102')),
#  ('12345', 'Shankar', 'Comp. Sci.', Decimal('32')),
#  ('19991', 'Brandt', 'History', Decimal('80')),
#  ('23121', 'Chavez', 'Finance', Decimal('110')),
#  ('44553', 'Peltier', 'Physics', Decimal('56')),
#  ('45678', 'Levy', 'Physics', Decimal('46')),
#  ('54321', 'Williams', 'Comp. Sci.', Decimal('54')),
#  ('55739', 'Sanchez', 'Music', Decimal('38')),
#  ('70557', 'Snow', 'Physics', Decimal('0')),
#  ('76543', 'Brown', 'Comp. Sci.', Decimal('58')),
#  ('76653', 'Aoi', 'Elec. Eng.', Decimal('60')),
#  ('98765', 'Bourikas', 'Elec. Eng.', Decimal('98')),
#  ('98988', 'Tanaka', 'Biology', Decimal('120'))]

# %% [markdown]
# ## PyCharm
#
# Required for Programming Track only, but recommended for all. Follow the instructions to setup PyCharm and run the test. Take a screenshot and insert it into the notebook using the cell below. You may have to change the path to the name and/or location of your image.

# %%
from IPython.display import Image 

Image("./ZiggyPyCharmScreenshot.png")

# %% [markdown]
# ## DataGrip
# Follow the instructions in the homework definition to setup DataGrip and connect DataGrip to MySQL. Insert your screenshot of the successful query on the sample database below. You may have to change the path to the name and/or location of your image.

# %%
Image("./ZiggyDataGrip.png")

# %% [markdown]
# The code below indicates how to connect this notebook to your AWS Database.
#
# You will need to change the username, password, and endpoint to match

# %% [markdown]
# __End of HW 0__
