# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
# </style>
#
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111: Introduction to Databases<br>
# Spring 2023, Sections 002, V02
# </span>
# </center></b>
# </span><br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# Non-Programming Track, HW2, Part 2<br>
# </span>
# </center></i>

# %% [markdown]
# # Introduction

# %% [markdown]
# ## Environment

# %% [markdown]
# - Test environment.
#
#
# - Set your MySQL user and password below.

# %%
mysql_user = "root"
mysql_pw = "dbuserdbuser"

# %%
# %load_ext sql

# %%
full_url = f"mysql+pymysql://{mysql_user}:{mysql_pw}@localhost"
full_url
# Out:
# 'mysql+pymysql://root:dbuserdbuser@localhost'

# %%
# %sql $full_url

# %%
# %sql select * from db_book.student;
# Out:
#  * mysql+pymysql://root:***@localhost
# 13 rows affected.
# [('00128', 'Zhang', 'Comp. Sci.', Decimal('102')),
#  ('12345', 'Shankar', 'Comp. Sci.', Decimal('32')),
#  ('19991', 'Brandt', 'History', Decimal('80')),
#  ('23121', 'Chavez', 'Finance', Decimal('110')),
#  ('44553', 'Peltier', 'Physics', Decimal('56')),
#  ('45678', 'Levy', 'Physics', Decimal('46')),
#  ('54321', 'Williams', 'Comp. Sci.', Decimal('54')),
#  ('55739', 'Sanchez', 'Music', Decimal('38')),
#  ('70557', 'Snow', 'Physics', Decimal('0')),
#  ('76543', 'Brown', 'Comp. Sci.', Decimal('58')),
#  ('76653', 'Aoi', 'Elec. Eng.', Decimal('60')),
#  ('98765', 'Bourikas', 'Elec. Eng.', Decimal('98')),
#  ('98988', 'Tanaka', 'Biology', Decimal('120'))]

# %% [markdown]
# ## Submission Instructions
#
# - See Ed for instructions.

# %% [markdown]
# # Data and Scheme Cleanup

# %% [markdown]
# ## characters and name_basics_all

# %% [markdown]
# - The task is to "clean up" ```characters``` and produce a table ```charactersFixed```.
#
#
# - The task will require adding missing rows to ```name_basics_all```. There are two row's in ```characters``` that have an ```actorLink``` and ```actorName``` got which there is no matching row in ```name_basics_all```.
#
#
# - ```characters``` has two actors with actorNames ```Barry John O'Connor``` and ```Barry O'Connor``` who are the same actor.
#
#
# - My ```charactersFixed``` has the following columns:
#     - ```characterId``` is a generated primary key. See below for an explanation.
#     - ```characterName```: The value from ```characters```.
#     - ```characterImdbID```: The ```characterLink``` from ```characters``` with ```/character/``` removed.
#     - ```characterLink```: The ```characterLink``` from ```characters```.
#     - ```actorNConst```: ```actorLink``` from ```characters```.
#     - ```actorLink```: A value of the form ```/names/``` followed by the ```actorNConst```.
#     - ```characterImageFull```: The value from ```characters```.
#     - ```characterImageThumb```: The value from ```characters```.
#     - ```kingsguard```: The value from ```characters```.
#     - ```royal```: The value from ```characters```.
#
#
# - The algorithm for generating the ```characterID``` on insert is the following:
#     - The prefix for the ```character``` is either:
#         - The substring of ```characterName``` preceeding the first ' '.
#         - The ```characterName``` is there is no ' '.
#     - If there are ```N``` rows in the table, the number after the prefix is ```N+1```.
#     - Implementing this is tricky. Your first attempt might rely on ```auto-increment```, but this does not work. You may also be tempted to count rows, but that does not work. A hint is that you will need to use a trigger and some other table/data that you create.
#
#
# - The directory with this notebook containers data from my version of ```charactersFixed```.
#
#
# - The cells below load the data to allow you to examine. In your SQL table, ```NaN``` will be ```NULL```.

# %%
import pandas as pd

# %%
characters_df = pd.read_csv('./charactersFixed.csv')

# %%
characters_df
# Out:
#     characterId        characterName characterImdbID         characterLink  \
# 0        Addam1       Addam Marbrand       ch0305333  /character/ch0305333
# 1        Aegon2      Aegon Targaryen             NaN                   NaN
# 2        Aeron3        Aeron Greyjoy       ch0540081  /character/ch0540081
# 3        Aerys4   Aerys II Targaryen       ch0541362  /character/ch0541362
# 4         Akho5                 Akho       ch0544520  /character/ch0544520
# ..          ...                  ...             ...                   ...
# 384    Young385            Young Nan       ch0305018  /character/ch0305018
# 385    Young386            Young Ned       ch0154681  /character/ch0154681
# 386    Young387      Young Ned Stark       ch0154681  /character/ch0154681
# 387    Young388  Young Rodrik Cassel       ch0171391  /character/ch0171391
# 388  Zanrush389              Zanrush       ch0540870  /character/ch0540870
#
#     actorNconst         actorLink  \
# 0     nm0389698  /names/nm0389698
# 1           NaN               NaN
# 2     nm0269923  /names/nm0269923
# 3     nm0727778  /names/nm0727778
# 4     nm6729880  /names/nm6729880
# ..          ...               ...
# 384   nm1519719  /names/nm1519719
# 385   nm7075019  /names/nm7075019
# 386   nm7509185  /names/nm7509185
# 387   nm7509186  /names/nm7509186
# 388   nm0503319  /names/nm0503319
#
#                                     characterImageFull  \
# 0                                                  NaN
# 1                                                  NaN
# 2    https://images-na.ssl-images-amazon.com/images...
# 3    https://images-na.ssl-images-amazon.com/images...
# 4    https://images-na.ssl-images-amazon.com/images...
# ..                                                 ...
# 384                                                NaN
# 385                                                NaN
# 386                                                NaN
# 387                                                NaN
# 388  https://images-na.ssl-images-amazon.com/images...
#
#                                    characterImageThumb  kingsguard  royal
# 0                                                  NaN         NaN    NaN
# 1                                                  NaN         NaN    1.0
# 2    https://images-na.ssl-images-amazon.com/images...         NaN    NaN
# 3    https://images-na.ssl-images-amazon.com/images...         NaN    1.0
# 4    https://images-na.ssl-images-amazon.com/images...         NaN    NaN
# ..                                                 ...         ...    ...
# 384                                                NaN         NaN    NaN
# 385                                                NaN         NaN    NaN
# 386                                                NaN         NaN    NaN
# 387                                                NaN         NaN    NaN
# 388  https://images-na.ssl-images-amazon.com/images...         NaN    NaN
#
# [389 rows x 10 columns]

# %% [markdown]
# - Your answer below should show all of your SQL statements, including DDL, for creating and loading ```charactersFixed``` as well as changes to ```name_basics_all```.
#
#
# - You can use the data in the CSV file to test your work. Show at least one test.

# %%
# Use my schema
# %sql USE s23_w4111_hw2_xc2605
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# #### Have a look at `characters`

# %%
# %sql SELECT * FROM characters LIMIT 12;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [('/character/ch0305333/', 'Addam Marbrand', 'nm0389698', 'B.J. Hogg', None, None, None, None),
#  (None, 'Aegon Targaryen', None, None, None, None, None, 1),
#  ('/character/ch0540081/', 'Aeron Greyjoy', 'nm0269923', 'Michael Feast', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzI5MDg0ZDAtN2Y2ZC00MzU1LTgyYjQtNTBjYjEzODczZDVhXkEyXkFqcGdeQXVyNTg0Nzg4NTE@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzI5MDg0ZDAtN2Y2ZC00MzU1LTgyYjQtNTBjYjEzODczZDVhXkEyXkFqcGdeQXVyNTg0Nzg4NTE@._V1._SX100_SY140_.jpg', None, None),
#  ('/character/ch0541362/', 'Aerys II Targaryen', 'nm0727778', 'David Rintoul', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWQzOWViN2ItNDZhOS00MmZlLTkxZTYtZDg5NGUwMGRmYWZjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWQzOWViN2ItNDZhOS00MmZlLTkxZTYtZDg5NGUwMGRmYWZjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, 1),
#  ('/character/ch0544520/', 'Akho', 'nm6729880', 'Chuku Modu', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGE4ZDZmOGUtNGE4Ny00Y2VmLThiOGItMjk3Y2U0ZDY3OWQxXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGE4ZDZmOGUtNGE4Ny00Y2VmLThiOGItMjk3Y2U0ZDY3OWQxXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('/character/ch0246938/', 'Alliser Thorne', 'nm0853583', 'Owen Teale', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAxMjExMjA3M15BMl5BanBnXkFtZTcwMjI1ODg5NA@@._V1_SY1000_CR0,0,666,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAxMjExMjA3M15BMl5BanBnXkFtZTcwMjI1ODg5NA@@._V1._SX100_SY140_.jpg', None, None),
#  ('/character/ch0305012/', 'Alton Lannister', 'nm0203801', 'Karl Davies', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU0NTU1NTAzOF5BMl5BanBnXkFtZTcwNzA2NDk4OA@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU0NTU1NTAzOF5BMl5BanBnXkFtZTcwNzA2NDk4OA@@._V1._SX100_SY140_.jpg', None, None),
#  ('/character/ch0576836/', 'Alys Karstark', 'nm8257864', 'Megan Parkinson', None, None, None, None),
#  ('/character/ch0305002/', 'Amory Lorch', 'nm0571654', 'Fintan McKeown', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTVmY2M2YmUtY2JkYS00NjIyLWFhYTAtNTNlZmI4ODdiNmE5XkEyXkFqcGdeQXVyMjg2MTMyNTM@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTVmY2M2YmUtY2JkYS00NjIyLWFhYTAtNTNlZmI4ODdiNmE5XkEyXkFqcGdeQXVyMjg2MTMyNTM@._V1._SX100_SY140_.jpg', None, None),
#  ('/character/ch0316930/', 'Anguy', 'nm1528121', 'Philip McGinley', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNmRhY2M4YmItNjc2Yi00ZDc0LWE5NmUtNGE5OWE0YTQ2YjY3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNmRhY2M4YmItNjc2Yi00ZDc0LWE5NmUtNGE5OWE0YTQ2YjY3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('/character/ch0578265/', 'Archmaester Marwyn', 'nm0000980', 'Jim Broadbent', None, None, None, None),
#  ('/character/ch0507107/', 'Areo Hotah', 'nm0649046', 'Deobia Oparei', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNWFkNTAwNzctOGQ2ZS00OTMyLWE3NDYtOGUwM2E1MzVlYjI0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNWFkNTAwNzctOGQ2ZS00OTMyLWE3NDYtOGUwM2E1MzVlYjI0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None)]

# %% [markdown]
# #### Indentify the missing rows in ```name_basics_all```.

# %%
# %%sql
# SELECT actorLink, actorName
# FROM characters
# WHERE actorLink NOT IN(
#     SELECT nconst FROM name_basics_all
# ) AND characterLink IS NOT NULL
# Out:
#  * mysql+pymysql://root:***@localhost
# 2 rows affected.
# [('nm3226454', "Barry John O'Connor"), ('nm8199963', 'Michael Patrick')]

# %% [markdown]
# #### Indeed, we got two of them

# %% [markdown]
# #### We insert them into `name_basics_all` and we can see that there is no missing rows

# %%
# %%sql
#
# INSERT INTO name_basics_all(nconst, primaryName)
# (SELECT actorLink, actorName
# FROM characters
# WHERE actorLink NOT IN(
#     SELECT nconst FROM name_basics_all
# ) AND characterLink IS NOT NULL);
# Out:
#  * mysql+pymysql://root:***@localhost
# 2 rows affected.
# []

# %%
# %%sql
# SELECT actorLink, actorName
# FROM characters
# WHERE actorLink NOT IN(
#     SELECT nconst FROM name_basics_all
# ) AND characterLink IS NOT NULL
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# #### There is no missing rows after our manipulation.

# %% [markdown]
# #### Handle "same actor" problem (See Ed ```https://edstem.org/us/courses/32981/discussion/2721113``` for instructor's clarification)

# %% [markdown]
# **See original data**

# %%
# %sql SELECT actorName, actorLink FROM characters WHERE actorName='Barry John O\'Connor'
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [("Barry John O'Connor", 'nm3226454')]

# %%
# %sql SELECT actorName, actorLink FROM characters WHERE actorName='Barry O\'Connor'
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [("Barry O'Connor", None)]

# %% [markdown]
# **Copy information**

# %%
# %%sql
#
# UPDATE characters c
# JOIN (SELECT actorName, actorLink FROM characters WHERE actorName='Barry John O\'Connor') temp
# ON c.actorName = 'Barry O\'Connor'
# SET c.actorLink = temp.actorLink;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# []

# %% [markdown]
# **See results (it works)**

# %%
# %sql SELECT actorName, actorLink FROM characters WHERE actorName='Barry John O\'Connor'
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [("Barry John O'Connor", 'nm3226454')]

# %%
# %sql SELECT actorName, actorLink FROM characters WHERE actorName='Barry O\'Connor'
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [("Barry O'Connor", 'nm3226454')]

# %% [markdown]
# ### create a new table (charactersFixed)

# %%
# %%sql
#
# DROP TABLE IF EXISTS charactersFixed;
#
# CREATE TABLE charactersFixed
# (
#     characterID varchar(32) NOT NULL,
#     characterName varchar(32) NOT NULL,
#     characterImdbID varchar(64) DEFAULT NULL,
#     characterLink varchar(64) DEFAULT NULL,
#     actorNconst varchar(64) DEFAULT NULL,
#     actorLink varchar(64) DEFAULT NULL,
#     characterImageFull varchar(256) DEFAULT NULL,
#     characterImageThumb varchar(256) DEFAULT NULL,
#     kingsguard boolean DEFAULT NULL,
#     royal boolean DEFAULT NULL,
#     CONSTRAINT charactersFixed_pk
#         PRIMARY KEY (characterID)
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %sql DESCRIBE charactersFixed;
# Out:
#  * mysql+pymysql://root:***@localhost
# 10 rows affected.
# [('characterID', 'varchar(32)', 'NO', 'PRI', None, ''),
#  ('characterName', 'varchar(32)', 'NO', '', None, ''),
#  ('characterImdbID', 'varchar(64)', 'YES', '', None, ''),
#  ('characterLink', 'varchar(64)', 'YES', '', None, ''),
#  ('actorNconst', 'varchar(64)', 'YES', '', None, ''),
#  ('actorLink', 'varchar(64)', 'YES', '', None, ''),
#  ('characterImageFull', 'varchar(256)', 'YES', '', None, ''),
#  ('characterImageThumb', 'varchar(256)', 'YES', '', None, ''),
#  ('kingsguard', 'tinyint(1)', 'YES', '', None, ''),
#  ('royal', 'tinyint(1)', 'YES', '', None, '')]

# %% [markdown]
# #### This function is required to compute next ID

# %%
# %%sql
#
# DROP FUNCTION IF EXISTS compute_next_ID;
#
# CREATE FUNCTION compute_next_ID(characterName varchar(64)) RETURNS varchar(32)
#     READS SQL DATA
# BEGIN
#
#     DECLARE prefix varchar(32);
#     DECLARE count int;
#     DECLARE result varchar(32);
#
#     SET prefix = SUBSTRING_INDEX(characterName, ' ', 1);
#
#     SET count = (SELECT COUNT(*) FROM s23_w4111_hw2_xc2605.charactersFixed) + 1;
#
#     SET result = concat(prefix, count);
#
#     return result;
#
# end;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# #### This trigger is required to add the PK each time when we try to insert a row

# %%
# %%sql
#
# DROP TRIGGER IF EXISTS COMPUTE_ID;
#
# CREATE TRIGGER COMPUTE_ID
#     BEFORE INSERT
#     ON s23_w4111_hw2_xc2605.charactersFixed
#     FOR EACH ROW
# BEGIN
#     SET new.characterID = compute_next_ID(new.characterName);
# end;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# **Use this to insert data**

# %%
# %%sql
#
# # Delete all rows (To make sure that you never insert data multiple times)
# DELETE FROM charactersFixed;
#
# # Please note that the original characterLink has an extra '/', so we have to delete it
#
# # Insert all rows
# INSERT INTO charactersFixed (characterName, characterImdbID,
#                              characterLink, actorNConst,
#                              actorLink, characterImageFull,
#                              characterImageThumb, kingsguard, royal)
# SELECT characterName, SUBSTRING(characterLink, 12, LENGTH(characterLink) - 12),
#        SUBSTRING(characterLink, 1, LENGTH(characterLink) - 1), actorLink,
#        CONCAT('/names/', actorLink), characterImageFull,
#        characterImageThumb, kingsguard, royal
# FROM characters;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 389 rows affected.
# []

# %% [markdown]
# #### Compare our `charactersFixed` with the original dataframe sample table. See results using SELECT, part I (the table is too large, so we use three query to visualise)

# %%
# %%sql
# SELECT characterID, characterName, characterImdbID, characterLink, actorNconst, actorLink,
#        kingsguard, royal
# FROM charactersFixed;
# Out:
#  * mysql+pymysql://root:***@localhost
# 389 rows affected.
# [('Addam1', 'Addam Marbrand', 'ch0305333', '/character/ch0305333', 'nm0389698', '/names/nm0389698', None, None),
#  ('Aegon2', 'Aegon Targaryen', None, None, None, None, None, 1),
#  ('Aeron3', 'Aeron Greyjoy', 'ch0540081', '/character/ch0540081', 'nm0269923', '/names/nm0269923', None, None),
#  ('Aerys4', 'Aerys II Targaryen', 'ch0541362', '/character/ch0541362', 'nm0727778', '/names/nm0727778', None, 1),
#  ('Akho5', 'Akho', 'ch0544520', '/character/ch0544520', 'nm6729880', '/names/nm6729880', None, None),
#  ('Alliser6', 'Alliser Thorne', 'ch0246938', '/character/ch0246938', 'nm0853583', '/names/nm0853583', None, None),
#  ('Alton7', 'Alton Lannister', 'ch0305012', '/character/ch0305012', 'nm0203801', '/names/nm0203801', None, None),
#  ('Alys8', 'Alys Karstark', 'ch0576836', '/character/ch0576836', 'nm8257864', '/names/nm8257864', None, None),
#  ('Amory9', 'Amory Lorch', 'ch0305002', '/character/ch0305002', 'nm0571654', '/names/nm0571654', None, None),
#  ('Anguy10', 'Anguy', 'ch0316930', '/character/ch0316930', 'nm1528121', '/names/nm1528121', None, None),
#  ('Archmaester11', 'Archmaester Marwyn', 'ch0578265', '/character/ch0578265', 'nm0000980', '/names/nm0000980', None, None),
#  ('Areo12', 'Areo Hotah', 'ch0507107', '/character/ch0507107', 'nm0649046', '/names/nm0649046', None, None),
#  ('Armeca13', 'Armeca', 'ch0305014', '/character/ch0305014', 'nm1783582', '/names/nm1783582', None, None),
#  ('Arthur14', 'Arthur', 'ch0305326', '/character/ch0305326', 'nm8127149', '/names/nm8127149', None, None),
#  ('Arthur15', 'Arthur Dayne', 'ch0540097', '/character/ch0540097', 'nm1074361', '/names/nm1074361', 1, None),
#  ('Arya16', 'Arya Stark', 'ch0158604', '/character/ch0158604', 'nm3586035', '/names/nm3586035', None, None),
#  ('Baby17', 'Baby Sam', 'ch0547881', '/character/ch0547881', None, None, None, None),
#  ('Balon18', 'Balon Greyjoy', 'ch0292152', '/character/ch0292152', 'nm0538869', '/names/nm0538869', None, None),
#  ('Baratheon19', 'Baratheon Guard', 'ch0350989', '/character/ch0350989', 'nm4207240', '/names/nm4207240', None, None),
#  ('Barristan20', 'Barristan Selmy', 'ch0241346', '/character/ch0241346', 'nm0568400', '/names/nm0568400', None, None),
#  ('Benjen21', 'Benjen Stark', 'ch0153996', '/character/ch0153996', 'nm1152798', '/names/nm1152798', None, None),
#  ('Beric22', 'Beric Dondarrion', 'ch0305320', '/character/ch0305320', None, None, None, None),
#  ('Bianca23', 'Bianca', 'ch0541364', '/character/ch0541364', 'nm4730958', '/names/nm4730958', None, None),
#  ('Biter24', 'Biter', 'ch0305028', '/character/ch0305028', 'nm0429956', '/names/nm0429956', None, None),
#  ('Black25', 'Black Lorren', 'ch0266524', '/character/ch0266524', 'nm1978998', '/names/nm1978998', None, None),
#  ('Black26', 'Black Walder Rivers', 'ch0014591', '/character/ch0014591', 'nm1043031', '/names/nm1043031', None, None),
#  ('Bobono27', 'Bobono', 'ch0541790', '/character/ch0541790', 'nm5279916', '/names/nm5279916', None, None),
#  ('Bowen28', 'Bowen Marsh', 'ch0305036', '/character/ch0305036', 'nm1638006', '/names/nm1638006', None, None),
#  ('Bran30', 'Bran Stark', 'ch0234897', '/character/ch0234897', 'nm3652842', '/names/nm3652842', None, 1),
#  ('Brandon29', 'Brandon Stark', None, None, None, None, None, None),
#  ('Brea31', 'Brea', 'ch0539337', '/character/ch0539337', 'nm5106314', '/names/nm5106314', None, None),
#  ('Brienne32', 'Brienne of Tarth', 'ch0254503', '/character/ch0254503', 'nm3729225', '/names/nm3729225', 1, None),
#  ('Bronn33', 'Bronn', 'ch0241345', '/character/ch0241345', 'nm0283492', '/names/nm0283492', None, None),
#  ('Brother34', 'Brother Ray', 'ch0541878', '/character/ch0541878', 'nm0574534', '/names/nm0574534', None, None),
#  ('Brynden35', 'Brynden Tully', 'ch0381563', '/character/ch0381563', 'nm0751085', '/names/nm0751085', None, None),
#  ('Captain36', 'Captain of the Archers', 'ch0540864', '/character/ch0540864', 'nm1214477', '/names/nm1214477', None, None),
#  ('Catelyn37', 'Catelyn Stark', 'ch0145135', '/character/ch0145135', 'nm0265610', '/names/nm0265610', None, None),
#  ('Catspaw38', 'Catspaw Assassin', 'ch0305046', '/character/ch0305046', 'nm0734498', '/names/nm0734498', None, None),
#  ('Cersei39', 'Cersei Lannister', 'ch0159526', '/character/ch0159526', 'nm0372176', '/names/nm0372176', None, 1),
#  ('Child40', 'Child of the Forest', 'ch0414315', '/character/ch0414315', 'nm2456829', '/names/nm2456829', None, None),
#  ('Citadel41', 'Citadel Maester', 'ch0478670', '/character/ch0478670', 'nm0404809', '/names/nm0404809', None, None),
#  ('Colen42', 'Colen of Greenpools', 'ch0350989', '/character/ch0350989', 'nm4007028', '/names/nm4007028', None, None),
#  ('Craster43', 'Craster', 'ch0300218', '/character/ch0300218', 'nm0700059', '/names/nm0700059', None, None),
#  ('Daario44', 'Daario Naharis', 'ch0335040', '/character/ch0335040', None, None, None, None),
#  ('Daenerys45', 'Daenerys Targaryen', 'ch0158597', '/character/ch0158597', 'nm3592338', '/names/nm3592338', None, 1),
#  ('Dagmer46', 'Dagmer Cleftjaw', 'ch0304762', '/character/ch0304762', 'nm0408591', '/names/nm0408591', None, None),
#  ('Daisy47', 'Daisy', 'ch0305015', '/character/ch0305015', 'nm3996678', '/names/nm3996678', None, None),
#  ('Davos48', 'Davos Seaworth', 'ch0255396', '/character/ch0255396', 'nm0192377', '/names/nm0192377', None, None),
#  ('Dickon49', 'Dickon Tarly', 'ch0541363', '/character/ch0541363', None, None, None, None),
#  ('Dongo50', 'Dongo the Giant', 'ch0510932', '/character/ch0510932', 'nm1613839', '/names/nm1613839', None, None),
#  ('Donnel51', 'Donnel Waynwood', 'ch0544229', '/character/ch0544229', 'nm1368037', '/names/nm1368037', None, None),
#  ('Dontos52', 'Dontos Hollard', 'ch0305031', '/character/ch0305031', 'nm0915453', '/names/nm0915453', None, None),
#  ('Hugh107', 'Hugh of the Vale', 'ch0305026', '/character/ch0305026', 'nm2131630', '/names/nm2131630', None, None),
#  ('Illyrio108', 'Illyrio Mopatis', 'ch0172909', '/character/ch0172909', 'nm0019885', '/names/nm0019885', None, None),
#  ('Ilyn109', 'Ilyn Payne', 'ch0246254', '/character/ch0246254', 'nm3330122', '/names/nm3330122', None, None),
#  ('Irri110', 'Irri', 'ch0249444', '/character/ch0249444', 'nm3822505', '/names/nm3822505', None, None),
#  ('Izembaro111', 'Izembaro', 'ch0540561', '/character/ch0540561', 'nm0001290', '/names/nm0001290', None, None),
#  ('Jacks112', 'Jacks', 'ch0305034', '/character/ch0305034', 'nm4781280', '/names/nm4781280', None, None),
#  ('Jafer113', 'Jafer Flowers', None, None, None, None, None, None),
#  ('Jaime114', 'Jaime Lannister', 'ch0158527', '/character/ch0158527', 'nm0182666', '/names/nm0182666', 1, None),
#  ('Janos115', 'Janos Slynt', 'ch0300651', '/character/ch0300651', 'nm0141582', '/names/nm0141582', None, None),
#  ("Jaqen's117", "Jaqen's Disguise", 'ch0259179', '/character/ch0259179', 'nm0641433', '/names/nm0641433', None, None),
#  ('Jaqen116', "Jaqen H'ghar", 'ch0259179', '/character/ch0259179', 'nm0937239', '/names/nm0937239', None, None),
#  ('Jaremy118', 'Jaremy Rykker', 'ch0305324', '/character/ch0305324', 'nm4475335', '/names/nm4475335', None, None),
#  ('Jeor119', 'Jeor Mormont', 'ch0251492', '/character/ch0251492', 'nm0181920', '/names/nm0181920', None, None),
#  ('Jhiqui120', 'Jhiqui', 'ch0305044', '/character/ch0305044', 'nm4424689', '/names/nm4424689', None, None),
#  ('Joffrey121', 'Joffrey Baratheon', 'ch0156278', '/character/ch0156278', 'nm0322416', '/names/nm0322416', None, 1),
#  ('Jojen122', 'Jojen Reed', 'ch0316921', '/character/ch0316921', 'nm1032473', '/names/nm1032473', None, None),
#  ('Jon123', 'Jon Arryn', 'ch0251737', '/character/ch0251737', 'nm0822062', '/names/nm0822062', None, None),
#  ('Jon124', 'Jon Snow', 'ch0155777', '/character/ch0155777', 'nm3229685', '/names/nm3229685', None, 1),
#  ('Jonos125', 'Jonos Bracken', 'ch0305332', '/character/ch0305332', 'nm0639569', '/names/nm0639569', None, None),
#  ('Jorah126', 'Jorah Mormont', 'ch0158221', '/character/ch0158221', 'nm0322513', '/names/nm0322513', None, None),
#  ('Jory127', 'Jory Cassel', 'ch0245400', '/character/ch0245400', 'nm0803397', '/names/nm0803397', None, None),
#  ('Joyeuse128', 'Joyeuse Erenford', 'ch0304494', '/character/ch0304494', 'nm4958677', '/names/nm4958677', None, None),
#  ('Karl129', 'Karl Tanner', 'ch0396528', '/character/ch0396528', 'nm1218607', '/names/nm1218607', None, None),
#  ('Karsi130', 'Karsi', 'ch0512707', '/character/ch0512707', 'nm2171898', '/names/nm2171898', None, None),
#  ('Kayla131', 'Kayla', 'ch0431526', '/character/ch0431526', 'nm4768858', '/names/nm4768858', None, None),
#  ('Lyanna184', 'Lyanna Stark', 'ch0543804', '/character/ch0543804', 'nm4957233', '/names/nm4957233', None, None),
#  ('Lysa185', 'Lysa Arryn', 'ch0251736', '/character/ch0251736', 'nm0225483', '/names/nm0225483', None, None),
#  ('Mace186', 'Mace Tyrell', 'ch0384328', '/character/ch0384328', 'nm0004355', '/names/nm0004355', None, None),
#  ('Maester187', 'Maester Aemon', 'ch0246936', '/character/ch0246936', 'nm0891092', '/names/nm0891092', None, None),
#  ('Maester188', 'Maester Cressen', 'ch0255280', '/character/ch0255280', 'nm0203882', '/names/nm0203882', None, None),
#  ('Maester189', 'Maester Luwin', 'ch0171393', '/character/ch0171393', 'nm0838910', '/names/nm0838910', None, None),
#  ('Maester190', 'Maester Wolkan', 'ch0550545', '/character/ch0550545', 'nm1483416', '/names/nm1483416', None, None),
#  ('Mag191', 'Mag the Mighty', 'ch0510933', '/character/ch0510933', 'nm2807170', '/names/nm2807170', None, None),
#  ('Maggy192', 'Maggy', 'ch0334882', '/character/ch0334882', 'nm0562003', '/names/nm0562003', None, None),
#  ('Mago193', 'Mago', 'ch0379227', '/character/ch0379227', 'nm2162079', '/names/nm2162079', None, None),
#  ('Male194', 'Male Prostitute', 'ch0441614', '/character/ch0441614', 'nm4982614', '/names/nm4982614', None, None),
#  ('Malko195', 'Malko', 'ch0519184', '/character/ch0519184', 'nm0015382', '/names/nm0015382', None, None),
#  ('Mance196', 'Mance Rayder', 'ch0335039', '/character/ch0335039', 'nm0001354', '/names/nm0001354', None, None),
#  ('Mandon197', 'Mandon Moore', 'ch0306220', '/character/ch0306220', 'nm0243696', '/names/nm0243696', 1, None),
#  ('Manservant198', 'Manservant', 'ch0525536', '/character/ch0525536', 'nm6442298', '/names/nm6442298', None, None),
#  ('Marei199', 'Marei', 'ch0431527', '/character/ch0431527', 'nm4982706', '/names/nm4982706', None, None),
#  ("Margaery's201", "Margaery's Handmaiden", 'ch0270368', '/character/ch0270368', 'nm2983094', '/names/nm2983094', None, None),
#  ('Margaery200', 'Margaery Tyrell', 'ch0251974', '/character/ch0251974', 'nm1754059', '/names/nm1754059', None, None),
#  ('Marillion202', 'Marillion', 'ch0305001', '/character/ch0305001', 'nm2047170', '/names/nm2047170', None, None),
#  ('Martyn203', 'Martyn Lannister', 'ch0395355', '/character/ch0395355', 'nm2835616', '/names/nm2835616', None, None),
#  ('Masha204', 'Masha Heddle', 'ch0305314', '/character/ch0305314', 'nm3126053', '/names/nm3126053', None, None),
#  ('Matthos205', 'Matthos Seaworth', 'ch0305029', '/character/ch0305029', 'nm4523680', '/names/nm4523680', None, None),
#  ('Meera206', 'Meera Reed', 'ch0316928', '/character/ch0316928', 'nm1697771', '/names/nm1697771', None, None),
#  ('Meereen207', 'Meereen Slave Master', 'ch0525536', '/character/ch0525536', 'nm2911170', '/names/nm2911170', None, None),
#  ('Melessa208', 'Melessa Tarly', 'ch0541191', '/character/ch0541191', 'nm0819087', '/names/nm0819087', None, None),
#  ('Pyat262', 'Pyat Pree', 'ch0303952', '/character/ch0303952', 'nm0360171', '/names/nm0360171', None, None),
#  ('Pypar263', 'Pypar', 'ch0273477', '/character/ch0273477', 'nm1086981', '/names/nm1086981', None, None),
#  ('Qhono264', 'Qhono', 'ch0540066', '/character/ch0540066', 'nm7047874', '/names/nm7047874', None, None),
#  ('Qhorin265', 'Qhorin Halfhand', 'ch0303951', '/character/ch0303951', 'nm1409802', '/names/nm1409802', None, None),
#  ('Qotho266', 'Qotho', 'ch0246162', '/character/ch0246162', 'nm1502469', '/names/nm1502469', None, None),
#  ('Quaithe267', 'Quaithe', 'ch0305022', '/character/ch0305022', 'nm3671418', '/names/nm3671418', None, None),
#  ('Qyburn268', 'Qyburn', 'ch0316929', '/character/ch0316929', 'nm0504320', '/names/nm0504320', None, None),
#  ('Rakharo269', 'Rakharo', 'ch0251495', '/character/ch0251495', 'nm1175468', '/names/nm1175468', None, None),
#  ('Ramsay270', 'Ramsay Snow', 'ch0321004', '/character/ch0321004', 'nm3701064', '/names/nm3701064', None, None),
#  ('Randyll271', 'Randyll Tarly', 'ch0524408', '/character/ch0524408', 'nm0269077', '/names/nm0269077', None, None),
#  ('Rast272', 'Rast', 'ch0251498', '/character/ch0251498', 'nm4430828', '/names/nm4430828', None, None),
#  ('Rattleshirt273', 'Rattleshirt', 'ch0305888', '/character/ch0305888', None, None, None, None),
#  ('Razdal274', 'Razdal mo Eraz', 'ch0413591', '/character/ch0413591', 'nm1745190', '/names/nm1745190', None, None),
#  ('Red275', 'Red Keep Stableboy', 'ch0379229', '/character/ch0379229', 'nm4164318', '/names/nm4164318', None, None),
#  ('Red276', 'Red Priestess', 'ch0540866', '/character/ch0540866', 'nm4927489', '/names/nm4927489', None, None),
#  ('Red277', 'Red Priestess', 'ch0540866', '/character/ch0540866', 'nm3822462', '/names/nm3822462', None, None),
#  ('Renly278', 'Renly Baratheon', 'ch0246253', '/character/ch0246253', 'nm2167445', '/names/nm2167445', None, None),
#  ('Rhaegal279', 'Rhaegal', None, None, None, None, None, None),
#  ('Rhaegar280', 'Rhaegar Targaryen', None, None, None, None, None, 1),
#  ('Rhaego281', 'Rhaego', None, None, None, None, None, None),
#  ('Rhaella282', 'Rhaella Targaryen', None, None, None, None, None, 1),
#  ('Rhaenys283', 'Rhaenys Targaryen', None, None, None, None, None, 1),
#  ('Rickard284', 'Rickard Karstark', 'ch0305331', '/character/ch0305331', None, None, None, None),
#  ('Rickard285', 'Rickard Stark', None, None, None, None, None, None),
#  ('Rickon286', 'Rickon Stark', 'ch0233141', '/character/ch0233141', 'nm3280686', '/names/nm3280686', None, None),
#  ('Robb287', 'Robb Stark', 'ch0158596', '/character/ch0158596', 'nm0534635', '/names/nm0534635', None, 1),
#  ('Robert288', 'Robert Baratheon', 'ch0155776', '/character/ch0155776', 'nm0004692', '/names/nm0004692', None, 1),
#  ('Robett289', 'Robett Glover', 'ch0541747', '/character/ch0541747', 'nm0570570', '/names/nm0570570', None, None),
#  ('Todder343', 'Todder', 'ch0509452', '/character/ch0509452', 'nm3727276', '/names/nm3727276', None, None),
#  ('Tomard344', 'Tomard', 'ch0305325', '/character/ch0305325', 'nm4475303', '/names/nm4475303', None, None),
#  ('Tommen345', 'Tommen Baratheon', 'ch0256424', '/character/ch0256424', None, None, None, 1),
#  ('Tormund346', 'Tormund Giantsbane', 'ch0316925', '/character/ch0316925', 'nm1970465', '/names/nm1970465', None, None),
#  ('Trystane347', 'Trystane Martell', 'ch0506400', '/character/ch0506400', 'nm4514519', '/names/nm4514519', None, None),
#  ('Tycho348', 'Tycho Nestoris', 'ch0468190', '/character/ch0468190', 'nm0309693', '/names/nm0309693', None, None),
#  ('Tyene349', 'Tyene Sand', 'ch0468075', '/character/ch0468075', 'nm3065809', '/names/nm3065809', None, None),
#  ('Tyrion350', 'Tyrion Lannister', 'ch0146096', '/character/ch0146096', 'nm0227759', '/names/nm0227759', None, None),
#  ('Tywin351', 'Tywin Lannister', 'ch0242185', '/character/ch0242185', 'nm0001097', '/names/nm0001097', None, None),
#  ('Vala352', 'Vala', 'ch0539344', '/character/ch0539344', 'nm5159884', '/names/nm5159884', None, None),
#  ('Vardis353', 'Vardis Egen', 'ch0294458', '/character/ch0294458', 'nm1788152', '/names/nm1788152', None, None),
#  ('Varly354', 'Varly', 'ch0379226', '/character/ch0379226', 'nm1378721', '/names/nm1378721', None, None),
#  ('Viserion355', 'Viserion', None, None, None, None, None, None),
#  ('Viserys356', 'Viserys Targaryen', 'ch0155775', '/character/ch0155775', 'nm0516003', '/names/nm0516003', None, 1),
#  ('Walda357', 'Walda Bolton', 'ch0506401', '/character/ch0506401', 'nm3531913', '/names/nm3531913', None, None),
#  ('Walder358', 'Walder Frey', 'ch0305328', '/character/ch0305328', 'nm0103195', '/names/nm0103195', None, None),
#  ('Wallen359', 'Wallen', None, None, 'nm3226454', '/names/nm3226454', None, None),
#  ('Warlock360', 'Warlock', 'ch0539881', '/character/ch0539881', 'nm5390029', '/names/nm5390029', None, None),
#  ('Waymar361', 'Waymar Royce', 'ch0171390', '/character/ch0171390', 'nm3209935', '/names/nm3209935', None, None),
#  ('Wedding362', 'Wedding Band', 'ch0506962', '/character/ch0506962', 'nm1460176', '/names/nm1460176', None, None),
#  ('White363', 'White Walker', 'ch0304921', '/character/ch0304921', 'nm1613839', '/names/nm1613839', None, None),
#  ('White364', 'White Walker', 'ch0304921', '/character/ch0304921', 'nm1368643', '/names/nm1368643', None, None),
#  ('White365', 'White Walker', 'ch0304921', '/character/ch0304921', 'nm0516385', '/names/nm0516385', None, None),
#  ('White366', 'White Walker #2', 'ch0304921', '/character/ch0304921', 'nm1872855', '/names/nm1872855', None, None),
#  ('Wight367', 'Wight Wildling Girl', 'ch0305043', '/character/ch0305043', 'nm4422708', '/names/nm4422708', None, None),
#  ('Wildling368', 'Wildling Rioter', 'ch0348391', '/character/ch0348391', 'nm8199963', '/names/nm8199963', None, None),
#  ('Will369', 'Will', 'ch0171394', '/character/ch0171394', 'nm0916037', '/names/nm0916037', None, None),
#  ('Willem370', 'Willem Lannister', 'ch0395356', '/character/ch0395356', 'nm5624523', '/names/nm5624523', None, None),
#  ('Willis371', 'Willis Wode', 'ch0305315', '/character/ch0305315', 'nm4416560', '/names/nm4416560', None, None),
#  ('Wine372', 'Wine Merchant', 'ch0305323', '/character/ch0305323', 'nm0523047', '/names/nm0523047', None, None),
#  ('Winterfell373', 'Winterfell Shepherd', 'ch0306456', '/character/ch0306456', 'nm0214343', '/names/nm0214343', None, None),
#  ('Wun374', 'Wun Wun', 'ch0524621', '/character/ch0524621', 'nm1613839', '/names/nm1613839', None, None),
#  ('Wyllis375', 'Wyllis', 'ch0238584', '/character/ch0238584', 'nm4744043', '/names/nm4744043', None, None),
#  ('Xaro376', 'Xaro Xhoan Daxos', 'ch0303950', '/character/ch0303950', 'nm1996829', '/names/nm1996829', None, None),
#  ('Yara377', 'Yara Greyjoy', 'ch0300217', '/character/ch0300217', 'nm2247629', '/names/nm2247629', None, None),
#  ('Yezzan378', 'Yezzan zo Qaggaz', 'ch0470706', '/character/ch0470706', 'nm0162281', '/names/nm0162281', None, None),
#  ('Ygritte379', 'Ygritte', 'ch0304492', '/character/ch0304492', 'nm3310211', '/names/nm3310211', None, None),
#  ('Yohn380', 'Yohn Royce', 'ch0524546', '/character/ch0524546', 'nm0889338', '/names/nm0889338', None, None),
#  ('Yoren381', 'Yoren', 'ch0251493', '/character/ch0251493', 'nm0535837', '/names/nm0535837', None, None),
#  ('Young382', 'Young Benjen Stark', 'ch0153996', '/character/ch0153996', 'nm5502295', '/names/nm5502295', None, None),
#  ('Young383', 'Young Cersei Lannister', 'ch0159526', '/character/ch0159526', 'nm5309709', '/names/nm5309709', None, None),
#  ('Young384', 'Young Lyanna Stark', 'ch0543804', '/character/ch0543804', 'nm8108764', '/names/nm8108764', None, None),
#  ('Young385', 'Young Nan', 'ch0305018', '/character/ch0305018', 'nm1519719', '/names/nm1519719', None, None),
#  ('Young386', 'Young Ned', 'ch0154681', '/character/ch0154681', 'nm7075019', '/names/nm7075019', None, None),
#  ('Young387', 'Young Ned Stark', 'ch0154681', '/character/ch0154681', 'nm7509185', '/names/nm7509185', None, None),
#  ('Young388', 'Young Rodrik Cassel', 'ch0171391', '/character/ch0171391', 'nm7509186', '/names/nm7509186', None, None),
#  ('Zanrush389', 'Zanrush', 'ch0540870', '/character/ch0540870', 'nm0503319', '/names/nm0503319', None, None)]

# %% [markdown]
# #### See results using SELECT, part III (the table is too large, so we use three query to visualise)

# %%
# %%sql
# SELECT characterID, characterImageFull
# FROM charactersFixed;
# Out:
#  * mysql+pymysql://root:***@localhost
# 389 rows affected.
# [('Addam1', None),
#  ('Aegon2', None),
#  ('Aeron3', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzI5MDg0ZDAtN2Y2ZC00MzU1LTgyYjQtNTBjYjEzODczZDVhXkEyXkFqcGdeQXVyNTg0Nzg4NTE@._V1_.jpg'),
#  ('Aerys4', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWQzOWViN2ItNDZhOS00MmZlLTkxZTYtZDg5NGUwMGRmYWZjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg'),
#  ('Akho5', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGE4ZDZmOGUtNGE4Ny00Y2VmLThiOGItMjk3Y2U0ZDY3OWQxXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg'),
#  ('Alliser6', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAxMjExMjA3M15BMl5BanBnXkFtZTcwMjI1ODg5NA@@._V1_SY1000_CR0,0,666,1000_AL_.jpg'),
#  ('Alton7', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU0NTU1NTAzOF5BMl5BanBnXkFtZTcwNzA2NDk4OA@@._V1_.jpg'),
#  ('Alys8', None),
#  ('Amory9', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTVmY2M2YmUtY2JkYS00NjIyLWFhYTAtNTNlZmI4ODdiNmE5XkEyXkFqcGdeQXVyMjg2MTMyNTM@._V1_.jpg'),
#  ('Anguy10', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNmRhY2M4YmItNjc2Yi00ZDc0LWE5NmUtNGE5OWE0YTQ2YjY3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg'),
#  ('Archmaester11', None),
#  ('Areo12', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNWFkNTAwNzctOGQ2ZS00OTMyLWE3NDYtOGUwM2E1MzVlYjI0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg'),
#  ('Armeca13', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZ
 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc2NzU5ODk0MV5BMl5BanBnXkFtZTcwMzEyNDY2OQ@@._V1_SY1000_CR0,0,1503,1000_AL_.jpg'),
#  ('Yezzan378', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZDgyOTFhMzktNWE5MS00YTY3LTk0YTYtMjkyMjFkODIxOTJiXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg'),
#  ('Ygritte379', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg0NDA1Njk3Nl5BMl5BanBnXkFtZTcwOTQ2NDk4OQ@@._V1_SY1000_CR0,0,724,1000_AL_.jpg'),
#  ('Yohn380', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZjgwNDc4NGQtMmQyMS00YjMyLWFhZWUtZmM0MjRkYmNmNGExXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg'),
#  ('Yoren381', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTZjZWMwZWItYTdlNi00N2RmLWFlYjQtZTZlYTIxYTRkMWJlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg'),
#  ('Young382', None),
#  ('Young383', None),
#  ('Young384', None),
#  ('Young385', None),
#  ('Young386', None),
#  ('Young387', None),
#  ('Young388', None),
#  ('Zanrush389', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTJjYzk1MGMtNjE3Mi00NjE2LTkzMWUtNGRjODVlY2JmMmI5XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg')]

# %% [markdown]
# #### See results using SELECT, part III (the table is too large, so we use three query to visualise)

# %%
# %%sql
# SELECT characterID, characterImageThumb
# FROM charactersFixed;
# Out:
#  * mysql+pymysql://root:***@localhost
# 389 rows affected.
# [('Addam1', None),
#  ('Aegon2', None),
#  ('Aeron3', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzI5MDg0ZDAtN2Y2ZC00MzU1LTgyYjQtNTBjYjEzODczZDVhXkEyXkFqcGdeQXVyNTg0Nzg4NTE@._V1._SX100_SY140_.jpg'),
#  ('Aerys4', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWQzOWViN2ItNDZhOS00MmZlLTkxZTYtZDg5NGUwMGRmYWZjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Akho5', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGE4ZDZmOGUtNGE4Ny00Y2VmLThiOGItMjk3Y2U0ZDY3OWQxXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Alliser6', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAxMjExMjA3M15BMl5BanBnXkFtZTcwMjI1ODg5NA@@._V1._SX100_SY140_.jpg'),
#  ('Alton7', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU0NTU1NTAzOF5BMl5BanBnXkFtZTcwNzA2NDk4OA@@._V1._SX100_SY140_.jpg'),
#  ('Alys8', None),
#  ('Amory9', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTVmY2M2YmUtY2JkYS00NjIyLWFhYTAtNTNlZmI4ODdiNmE5XkEyXkFqcGdeQXVyMjg2MTMyNTM@._V1._SX100_SY140_.jpg'),
#  ('Anguy10', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNmRhY2M4YmItNjc2Yi00ZDc0LWE5NmUtNGE5OWE0YTQ2YjY3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Archmaester11', None),
#  ('Areo12', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNWFkNTAwNzctOGQ2ZS00OTMyLWE3NDYtOGUwM2E1MzVlYjI0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Armeca13', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZmQyMGVlMDctYWFhMi00YzMyLTlkZDgtOWNmZTY3NmZkYzZlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Arthur14', None),
#  ('Arthur15', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODczZDUxYmQtMzk1MC00ZTUwLTk1MjAtZDJlODViMWFhOGU5XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Arya16', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk5MTYwNDc0OF5BMl5BanBnXkFtZTcwOTg2NDg1Nw@@._V1._SX100_SY140_.jpg'),
#  ('Baby17', None),
#  ('Balon18', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTUxNjkwODczN15BMl5BanBnXkFtZTcwODMwNTgzNw@@._V1._SX100_SY140_.jpg'),
#  ('Baratheon19', None),
#  ('Barristan20', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTUyMTE0NjUxNV5BMl5BanBnXkFtZTcwOTA1ODg5NA@@._V1._SX100_SY140_.jpg'),
#  ('Benjen21', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjFiY2M5MjgtZmRiMS00ZTAyLTk2Y2UtMjdjZTRkZmVlYTMyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Beric22', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjQwMTEwNTg2MF5BMl5BanBnXkFtZTgwNTAxODYxOTE@._V1._SX100_SY140_.jpg'),
#  ('Bianca23', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYWJhYjcxYzgtMDlhZi00OGNhLWE0NzAtMWFhMDJlYTZmYzY2XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Biter24', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjQ1ZWY3NTYtNmYzZS00ZDQyLThhMDItYTQyNmU0ZDg5NWViL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_SY100_SX100_AL_.jpg'),
#  ('Black25', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjg5ZGZjZDUtZmJmNC00MjQ5LWJhZDAtOTc0MzYzNTNkMTZiXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Black26', None),
#  ('Bobono27', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZWRmNWVhNTctOGJlZC00ZjVlLThkY2MtODU3Y2I2Njc1YzZjL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Bowen28', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNmRkMDYxYjQtYTBjZi00NDZlLThmNGMtYzlhNGI1ZDE5NTJmXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Bran30', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA
 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTYwNzc0MDUzNF5BMl5BanBnXkFtZTcwMDc1NzE5OQ@@._V1._SX100_SY140_.jpg'),
#  ('Three-Eyed340', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGI4NGRiNTUtM2ZlYy00ZjhlLWJlYWItMjgzNWIzYWQwZWY0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Timett341', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTM5MjU1NzA1NF5BMl5BanBnXkFtZTcwOTA2Nzk1NQ@@._V1._SX100_SY140_.jpg'),
#  ('Tobho342', None),
#  ('Todder343', None),
#  ('Tomard344', None),
#  ('Tommen345', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTY1YWUxM2QtZjhmZC00ZmQ2LThkM2YtNTk2MmQ5OTk3NGMyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Tormund346', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc1OTU3NjUzNF5BMl5BanBnXkFtZTcwNDE0NzE5OQ@@._V1._SX100_SY140_.jpg'),
#  ('Trystane347', 'https://m.media-amazon.com/images/M/MV5BODkzNjY0NTA0MV5BMl5BanBnXkFtZTgwNjc1NDE3NTE@._V1_SX100_CR0,0,100,100_AL_.jpg'),
#  ('Tycho348', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTFjYWJjZTEtM2Y1Zi00YzE0LTkzOTItZGZkNzM2YjBiNjg5XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Tyene349', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNDY5NzBiMTQtYzhmMS00Y2FmLTkzYzYtYzM2ODBjNGZlNGNiXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Tyrion350', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA2MDAwOTI0OV5BMl5BanBnXkFtZTcwNjA3NDg1Nw@@._V1._SX100_SY140_.jpg'),
#  ('Tywin351', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTA4ODMxMzE1OV5BMl5BanBnXkFtZTcwMTM0ODg4OQ@@._V1._SX100_SY140_.jpg'),
#  ('Vala352', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYzdiYzllYjMtMGJmNC00NWIwLWIwMzEtOTM1Mjk4ZTkxZDM1XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Vardis353', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMzg1Y2NiYTYtNDY0Yi00OGMwLWJjZjktZDVlNDE1Y2M3MTMzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Varly354', None),
#  ('Viserion355', None),
#  ('Viserys356', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTgwNzIxMTU1OV5BMl5BanBnXkFtZTcwNzI2ODg5NA@@._V1._SX100_SY140_.jpg'),
#  ('Walda357', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTZiNWE2YTYtZDA2Ny00ZmUwLTk4ZWUtZjFkM2JkYjFiNjE3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Walder358', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYzU0YzZjMTktZDA2Ni00YTRhLWFkZTgtOTQ4Yjg2MmQ2OGUzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Wallen359', None),
#  ('Warlock360', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMzE0NjExMGMtYjJlOC00MWI4LTg5MTgtYTIzZTgxZjc2NDAyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Waymar361', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYzE1Y2EwN2QtMzMzZS00MDZkLTg4ZjItN2NkNGNkYjAzZGVlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Wedding362', None),
#  ('White363', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYzNDMyZWUtMDVlMy00OGQxLWFkZTctOWMxZDk1MDA5MmQzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('White364', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYzNDMyZWUtMDVlMy00OGQxLWFkZTctOWMxZDk1MDA5MmQzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('White365', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYzNDMyZWUtMDVlMy00OGQxLWFkZTctOWMxZDk1MDA5MmQzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('White366', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYzNDMyZWUtMDVlMy00OGQxLWFkZTctOWMxZDk1MDA5MmQzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Wight367', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTg0OTdiOTYtNjBlYS00ZjI1LWEzMTAtODExOWRhNDZhMWNhXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Wildling368', None),
#  ('Will369', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA0NjU2MjIzNF5BMl5BanBnXkFtZTgwNzEyODI1MDI@._V1_SY100_CR16,0,100,100_AL_.jpg'),
#  ('Willem370', None),
#  ('Willis371', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMmY3NWI0YTItNWFkZi00MTVlLWIyNDQtN2MwYjY0ZjhhOTdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Wine372', None),
#  ('Winterfell373', None),
#  ('Wun374', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTFjMTczNTQtNzE5MC00ZTI1LWI0ZGMtMTA4NGU2ZGQ5ZjRkXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1._SX100_SY140_.jpg'),
#  ('Wyllis375', None),
#  ('Xaro376', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU3NTA5NDA3NF5BMl5BanBnXkFtZTcwNzY2NDg1Nw@@._V1._SX100_SY140_.jpg'),
#  ('Yara377', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc2NzU5ODk0MV5BMl5BanBnXkFtZTcwMzEyNDY2OQ@@._V1._SX100_SY140_.jpg'),
#  ('Yezzan378', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZDgyOTFhMzktNWE5MS00YTY3LTk0YTYtMjkyMjFkODIxOTJiXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Ygritte379', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg0NDA1Njk3Nl5BMl5BanBnXkFtZTcwOTQ2NDk4OQ@@._V1._SX100_SY140_.jpg'),
#  ('Yohn380', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZjgwNDc4NGQtMmQyMS00YjMyLWFhZWUtZmM0MjRkYmNmNGExXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Yoren381', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTZjZWMwZWItYTdlNi00N2RmLWFlYjQtZTZlYTIxYTRkMWJlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg'),
#  ('Young382', None),
#  ('Young383', None),
#  ('Young384', None),
#  ('Young385', None),
#  ('Young386', None),
#  ('Young387', None),
#  ('Young388', None),
#  ('Zanrush389', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTJjYzk1MGMtNjE3Mi00NjE2LTkzMWUtNGRjODVlY2JmMmI5XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg')]

# %% [markdown]
# ## name_basics_all

# %% [markdown]
# - The column ```primaryProfessions``` is multi-valued and non-atomic. This violates good relational design principle.

# %% [markdown]
# ## Summary about what I will do

# %% [markdown]
# ### *To deal with multi-valued and non-atomic columns, I split them and use relationable tables to set them up. 1. We drop the columns in `name_basics_all_fixed` that is not atomic/multi-valued; 2. We split the `primaryName` to `firstName` and `lastName`; 3. We create realtionable table for `primaryProfession` and `knownForTitles`, and corresponding tables that contain all possible value in them (`profession_values` and `title_values`). This is a very common very in handling with multi-valued columns.*

# %% [markdown]
# #### First, create a new table `name_basics_all_fixed`.

# %%
# %%sql
# # simply copy the original table and drop the column 'primaryProfession'
# DROP TABLE IF EXISTS name_basics_all_fixed;
# CREATE TABLE IF NOT EXISTS name_basics_all_fixed LIKE name_basics_all;
# INSERT name_basics_all_fixed SELECT * FROM name_basics_all;
# ALTER TABLE name_basics_all_fixed
# DROP COLUMN primaryProfession;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# 350 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# #### Have a look at the old `name_basics_all` table

# %%
# %sql SELECT * FROM name_basics_all LIMIT 12;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [('nm0389698', 'B.J. Hogg', '1955', '2020', 'actor,music_department', 'tt0970411,tt0944947,tt0986233,tt1240982'),
#  ('nm0269923', 'Michael Feast', '1946', None, 'actor,composer', 'tt0472160,tt0162661,tt0120879,tt0362192'),
#  ('nm0727778', 'David Rintoul', '1948', None, 'actor', 'tt1655420,tt1139328,tt4786824,tt6079772'),
#  ('nm6729880', 'Chuku Modu', '1990', None, 'actor,writer,producer', 'tt4154664,tt2674426,tt6470478,tt0944947'),
#  ('nm0853583', 'Owen Teale', '1961', None, 'actor', 'tt0102797,tt0485301,tt0462396,tt0944947'),
#  ('nm0203801', 'Karl Davies', '1982', None, 'actor,producer', 'tt12879632,tt7366338,tt3428912,tt0944947'),
#  ('nm8257864', 'Megan Parkinson', None, None, 'actress', 'tt0944947,tt6636246,tt5761478,tt4276618'),
#  ('nm0571654', 'Fintan McKeown', None, None, 'actor', 'tt0944947,tt0111904,tt0166396,tt0112178'),
#  ('nm1528121', 'Philip McGinley', '1981', None, 'actor', 'tt3922704,tt0053494,tt0944947,tt1446714'),
#  ('nm0000980', 'Jim Broadbent', '1949', None, 'actor,writer,soundtrack', 'tt0203009,tt1431181,tt1007029,tt0217505'),
#  ('nm0649046', 'Deobia Oparei', '1971', None, 'actor', 'tt0419706,tt0118929,tt0203009,tt1343727'),
#  ('nm1783582', 'Sahara Knite', '1975', None, 'actress', 'tt15288590,tt15249564,tt0944947,tt9814116')]

# %% [markdown]
# #### Have a look at the new `name_basics_all_fixed` table

# %%
# %sql SELECT * FROM name_basics_all_fixed LIMIT 12;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [('nm0389698', 'B.J. Hogg', '1955', '2020', 'tt0970411,tt0944947,tt0986233,tt1240982'),
#  ('nm0269923', 'Michael Feast', '1946', None, 'tt0472160,tt0162661,tt0120879,tt0362192'),
#  ('nm0727778', 'David Rintoul', '1948', None, 'tt1655420,tt1139328,tt4786824,tt6079772'),
#  ('nm6729880', 'Chuku Modu', '1990', None, 'tt4154664,tt2674426,tt6470478,tt0944947'),
#  ('nm0853583', 'Owen Teale', '1961', None, 'tt0102797,tt0485301,tt0462396,tt0944947'),
#  ('nm0203801', 'Karl Davies', '1982', None, 'tt12879632,tt7366338,tt3428912,tt0944947'),
#  ('nm8257864', 'Megan Parkinson', None, None, 'tt0944947,tt6636246,tt5761478,tt4276618'),
#  ('nm0571654', 'Fintan McKeown', None, None, 'tt0944947,tt0111904,tt0166396,tt0112178'),
#  ('nm1528121', 'Philip McGinley', '1981', None, 'tt3922704,tt0053494,tt0944947,tt1446714'),
#  ('nm0000980', 'Jim Broadbent', '1949', None, 'tt0203009,tt1431181,tt1007029,tt0217505'),
#  ('nm0649046', 'Deobia Oparei', '1971', None, 'tt0419706,tt0118929,tt0203009,tt1343727'),
#  ('nm1783582', 'Sahara Knite', '1975', None, 'tt15288590,tt15249564,tt0944947,tt9814116')]

# %% [markdown]
# #### Further drop `primaryName` and `knownForTitles`.

# %%
# %%sql
# ALTER TABLE name_basics_all_fixed
# DROP COLUMN primaryName;
# ALTER TABLE name_basics_all_fixed
# DROP COLUMN knownForTitles;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# #### Now, it only `nconst` as an identifier

# %%
# %sql SELECT * FROM name_basics_all_fixed LIMIT 12;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [('nm0389698', '1955', '2020'),
#  ('nm0269923', '1946', None),
#  ('nm0727778', '1948', None),
#  ('nm6729880', '1990', None),
#  ('nm0853583', '1961', None),
#  ('nm0203801', '1982', None),
#  ('nm8257864', None, None),
#  ('nm0571654', None, None),
#  ('nm1528121', '1981', None),
#  ('nm0000980', '1949', None),
#  ('nm0649046', '1971', None),
#  ('nm1783582', '1975', None)]

# %% [markdown]
# - Create a new table ```name_basics_all_fixed``` which does not have the column ```primaryProfessions```.

# %% [markdown]
# #### we now use the original data to handle multi-value attributes.

# %% [markdown]
# #### As required in the OHs (`https://cvn.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=7eb8cb14-0cd1-4fd9-835a-afc000054522 around` 28 mins), we firstly modify `primaryName` to `firstName` and `lastName`

# %% [markdown]
# #### Add these two columns back

# %%
# %%sql
#
# ALTER TABLE name_basics_all_fixed
# ADD firstName varchar(32) DEFAULT NULL;
# ALTER TABLE name_basics_all_fixed
# ADD lastName varchar(32) DEFAULT NULL;
#
# SELECT * FROM name_basics_all_fixed LIMIT 12;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# 12 rows affected.
# [('nm0389698', '1955', '2020', None, None),
#  ('nm0269923', '1946', None, None, None),
#  ('nm0727778', '1948', None, None, None),
#  ('nm6729880', '1990', None, None, None),
#  ('nm0853583', '1961', None, None, None),
#  ('nm0203801', '1982', None, None, None),
#  ('nm8257864', None, None, None, None),
#  ('nm0571654', None, None, None, None),
#  ('nm1528121', '1981', None, None, None),
#  ('nm0000980', '1949', None, None, None),
#  ('nm0649046', '1971', None, None, None),
#  ('nm1783582', '1975', None, None, None)]

# %% [markdown]
# #### Split names have a look at the resutls

# %%
# %%sql
#
# SELECT
#       nconst,
#       SUBSTR(primaryName, 1, LOCATE(' ', primaryName)) AS firstName,
#       SUBSTR(primaryName, LOCATE(' ', primaryName) + 1) AS lastName
# FROM name_basics_all
# LIMIT 12;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [('nm0389698', 'B.J. ', 'Hogg'),
#  ('nm0269923', 'Michael ', 'Feast'),
#  ('nm0727778', 'David ', 'Rintoul'),
#  ('nm6729880', 'Chuku ', 'Modu'),
#  ('nm0853583', 'Owen ', 'Teale'),
#  ('nm0203801', 'Karl ', 'Davies'),
#  ('nm8257864', 'Megan ', 'Parkinson'),
#  ('nm0571654', 'Fintan ', 'McKeown'),
#  ('nm1528121', 'Philip ', 'McGinley'),
#  ('nm0000980', 'Jim ', 'Broadbent'),
#  ('nm0649046', 'Deobia ', 'Oparei'),
#  ('nm1783582', 'Sahara ', 'Knite')]

# %% [markdown]
# #### Insert them

# %%
# %%sql
#
# UPDATE name_basics_all_fixed nf
# JOIN (SELECT
#       nconst,
#       SUBSTR(primaryName, 1, LOCATE(' ', primaryName)) AS firstName,
#       SUBSTR(primaryName, LOCATE(' ', primaryName) + 1) AS lastName
# FROM name_basics_all) temp
# ON nf.nconst = temp.nconst
# SET nf.firstName = temp.firstName, nf.lastName = temp.lastName;
# Out:
#  * mysql+pymysql://root:***@localhost
# 350 rows affected.
# []

# %% [markdown]
# #### All `firstName` and `lastName` added

# %%
# %sql SELECT * FROM name_basics_all_fixed LIMIT 12;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [('nm0389698', '1955', '2020', 'B.J. ', 'Hogg'),
#  ('nm0269923', '1946', None, 'Michael ', 'Feast'),
#  ('nm0727778', '1948', None, 'David ', 'Rintoul'),
#  ('nm6729880', '1990', None, 'Chuku ', 'Modu'),
#  ('nm0853583', '1961', None, 'Owen ', 'Teale'),
#  ('nm0203801', '1982', None, 'Karl ', 'Davies'),
#  ('nm8257864', None, None, 'Megan ', 'Parkinson'),
#  ('nm0571654', None, None, 'Fintan ', 'McKeown'),
#  ('nm1528121', '1981', None, 'Philip ', 'McGinley'),
#  ('nm0000980', '1949', None, 'Jim ', 'Broadbent'),
#  ('nm0649046', '1971', None, 'Deobia ', 'Oparei'),
#  ('nm1783582', '1975', None, 'Sahara ', 'Knite')]

# %% [markdown]
# #### Modify and describe the name fixed all table

# %%
# %%sql
#
# ALTER TABLE name_basics_all_fixed
# MODIFY COLUMN birthYear int DEFAULT NULL;
# ALTER TABLE name_basics_all_fixed
# MODIFY COLUMN deathYear int DEFAULT NULL;
# ALTER TABLE name_basics_all_fixed
# ADD PRIMARY KEY (nconst);
# Out:
#  * mysql+pymysql://root:***@localhost
# 350 rows affected.
# 350 rows affected.
# 0 rows affected.
# []

# %%
# %sql DESCRIBE name_basics_all_fixed;
# Out:
#  * mysql+pymysql://root:***@localhost
# 5 rows affected.
# [('nconst', 'varchar(16)', 'NO', 'PRI', None, ''),
#  ('birthYear', 'int', 'YES', '', None, ''),
#  ('deathYear', 'int', 'YES', '', None, ''),
#  ('firstName', 'varchar(32)', 'YES', '', None, ''),
#  ('lastName', 'varchar(32)', 'YES', '', None, '')]

# %% [markdown]
# #### Now, we modify `primaryProfession`, we first create a realtionship table (As required in the lecture `https://cvn.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=699aedd8-1fcf-4593-86a8-afba012f802e` 1:42:09)

# %% [markdown]
# #### Split `primaryProfession`

# %%
# %%sql
#
# SELECT
#       nconst,
#       SUBSTRING_INDEX(primaryProfession, ',', 1) AS p1,
#       NULLIF(SUBSTRING_INDEX(SUBSTRING_INDEX(primaryProfession, ',', 2), ',', -1),
#         SUBSTRING_INDEX(primaryProfession, ',', 1)) AS p2,
#       NULLIF(SUBSTRING_INDEX(SUBSTRING_INDEX(primaryProfession, ',', 3), ',', -1),
#         SUBSTRING_INDEX(SUBSTRING_INDEX(primaryProfession, ',', 2), ',', -1)) AS p3
# FROM name_basics_all
# LIMIT 12;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [('nm0389698', 'actor', 'music_department', None),
#  ('nm0269923', 'actor', 'composer', None),
#  ('nm0727778', 'actor', None, None),
#  ('nm6729880', 'actor', 'writer', 'producer'),
#  ('nm0853583', 'actor', None, None),
#  ('nm0203801', 'actor', 'producer', None),
#  ('nm8257864', 'actress', None, None),
#  ('nm0571654', 'actor', None, None),
#  ('nm1528121', 'actor', None, None),
#  ('nm0000980', 'actor', 'writer', 'soundtrack'),
#  ('nm0649046', 'actor', None, None),
#  ('nm1783582', 'actress', None, None)]

# %% [markdown]
# #### Create a relationship table to store `nconst` and professions with atomic columns ONLY

# %%
# %%sql
#
# DROP TABLE IF EXISTS name_profession;
#
# CREATE TABLE name_profession AS
#
# WITH temp1 AS
# (SELECT
#       nconst,
#       SUBSTRING_INDEX(primaryProfession, ',', 1) AS p1,
#       NULLIF(SUBSTRING_INDEX(SUBSTRING_INDEX(primaryProfession, ',', 2), ',', -1),
#         SUBSTRING_INDEX(primaryProfession, ',', 1)) AS p2,
#       NULLIF(SUBSTRING_INDEX(SUBSTRING_INDEX(primaryProfession, ',', 3), ',', -1),
#         SUBSTRING_INDEX(SUBSTRING_INDEX(primaryProfession, ',', 2), ',', -1)) AS p3
# FROM name_basics_all)
#
# SELECT nconst, p1 AS professionName FROM temp1
#                                     WHERE p1 IS NOT NULL
# UNION
# SELECT nconst, p2 AS professionName FROM temp1
#                                     WHERE p2 IS NOT NULL
# UNION
# SELECT nconst, p3 AS professionName FROM temp1
#                                     WHERE p3 IS NOT NULL
# ORDER BY nconst
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 610 rows affected.
# []

# %% [markdown]
# #### This table contains `nconst` as identifier and their corresponding professions

# %%
# %%sql
#
# SELECT * FROM name_profession LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost
# 20 rows affected.
# [('nm0000293', 'actor'),
#  ('nm0000293', 'producer'),
#  ('nm0000293', 'animation_department'),
#  ('nm0000596', 'actor'),
#  ('nm0000596', 'producer'),
#  ('nm0000596', 'soundtrack'),
#  ('nm0000980', 'writer'),
#  ('nm0000980', 'actor'),
#  ('nm0000980', 'soundtrack'),
#  ('nm0001097', 'director'),
#  ('nm0001097', 'writer'),
#  ('nm0001097', 'actor'),
#  ('nm0001290', 'soundtrack'),
#  ('nm0001290', 'actor'),
#  ('nm0001290', 'director'),
#  ('nm0001354', 'actor'),
#  ('nm0001354', 'soundtrack'),
#  ('nm0001671', 'actress'),
#  ('nm0001671', 'costume_department'),
#  ('nm0001671', 'soundtrack')]

# %% [markdown]
# #### Then create a table to get values of profession. This table contains all possible profession names (`profession_values`).

# %%
# %%sql
# DROP TABLE IF EXISTS profession_values;
#
# CREATE TABLE profession_values AS
# SELECT DISTINCT professionName FROM name_profession;
#
# ALTER TABLE profession_values
# MODIFY COLUMN professionName varchar(64);
#
# ALTER TABLE profession_values
# ADD PRIMARY KEY (professionName);
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 28 rows affected.
# 28 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# #### 28 professions in total.

# %%
# %%sql
#
# SELECT * FROM profession_values;
# Out:
#  * mysql+pymysql://root:***@localhost
# 28 rows affected.
# [('actor',),
#  ('actress',),
#  ('animation_department',),
#  ('art_department',),
#  ('assistant_director',),
#  ('camera_department',),
#  ('casting_department',),
#  ('casting_director',),
#  ('cinematographer',),
#  ('composer',),
#  ('costume_department',),
#  ('director',),
#  ('editor',),
#  ('executive',),
#  ('make_up_department',),
#  ('miscellaneous',),
#  ('music_department',),
#  ('producer',),
#  ('production_manager',),
#  ('script_department',),
#  ('set_decorator',),
#  ('sound_department',),
#  ('soundtrack',),
#  ('stunts',),
#  ('talent_agent',),
#  ('transportation_department',),
#  ('visual_effects',),
#  ('writer',)]

# %% [markdown]
# #### We now set FKs for `name_profession`

# %%
# %%sql
#
# ALTER TABLE name_profession
# MODIFY COLUMN professionName varchar(64);
#
# ALTER TABLE name_profession
# ADD FOREIGN KEY (nconst) REFERENCES name_basics_all_fixed(nconst);
#
# ALTER TABLE name_profession
# ADD FOREIGN KEY (professionName) REFERENCES profession_values(professionName);
# Out:
#  * mysql+pymysql://root:***@localhost
# 610 rows affected.
# 610 rows affected.
# 610 rows affected.
# []

# %% [markdown]
# #### See what we have created

# %%
# %sql DESCRIBE profession_values;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [('professionName', 'varchar(64)', 'NO', 'PRI', None, '')]

# %%
# %sql DESCRIBE name_profession;
# Out:
#  * mysql+pymysql://root:***@localhost
# 2 rows affected.
# [('nconst', 'varchar(16)', 'NO', 'MUL', '', ''),
#  ('professionName', 'varchar(64)', 'YES', 'MUL', None, '')]

# %% [markdown]
# #### Finally, as instructed in BOTH the OHs and the lectures. We need to create a similar pattern for titles, and the relationship table is just the `title_principals` in the original dataset.

# %% [markdown]
# #### Count number of rows in `title_principals`

# %%
# %sql SELECT COUNT(*) FROM title_principals;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [(730,)]

# %% [markdown]
# #### We want to clean up the table because we need to set up a foreign key later

# %%
# %%sql
#
# DELETE
# FROM title_principals
# WHERE nconst NOT IN(
#     SELECT nconst FROM name_basics_all_fixed
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 407 rows affected.
# []

# %% [markdown]
# #### Unfortunately, however, if we have a quick look at the new data, it does consistent with our data (in `name_basics_all`, where each `nconst` has at most four titles), also there are too many rows missing.

# %%
# %sql SELECT nconst, count(tconst) AS numberOfKnownForTitles FROM title_principals GROUP BY nconst LIMIT 12;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [('nm0000293', 10),
#  ('nm0004692', 7),
#  ('nm0182666', 55),
#  ('nm0265610', 17),
#  ('nm0372176', 57),
#  ('nm3592338', 49),
#  ('nm0227759', 58),
#  ('nm0318821', 7),
#  ('nm0001097', 2),
#  ('nm0192377', 2),
#  ('nm3229685', 19),
#  ('nm0628040', 31)]

# %% [markdown]
# ## Have a look at this Ed `https://edstem.org/us/courses/32981/discussion/2725932`. This homework primiarly focus on `professionName`. It is possible to clean up the data, add missing rows, delete extra rows, but there are too much such rows missing/redundant, which actually makes the `titlePrincipal` table meaningless. So we create our own `title_principals_fixed`. Simiar to our previous manipulation regarding to `professionName`

# %% [markdown]
# #### Split the column, `knownForTitles`

# %%
# %%sql
#
# SELECT
#       nconst,
#       SUBSTRING_INDEX(knownForTitles, ',', 1) AS t1,
#       NULLIF(SUBSTRING_INDEX(SUBSTRING_INDEX(knownForTitles, ',', 2), ',', -1),
#         SUBSTRING_INDEX(knownForTitles, ',', 1)) AS t2,
#       NULLIF(SUBSTRING_INDEX(SUBSTRING_INDEX(knownForTitles, ',', 3), ',', -1),
#         SUBSTRING_INDEX(SUBSTRING_INDEX(knownForTitles, ',', 2), ',', -1)) AS t3,
#       NULLIF(SUBSTRING_INDEX(SUBSTRING_INDEX(knownForTitles, ',', 4), ',', -1),
#         SUBSTRING_INDEX(SUBSTRING_INDEX(knownForTitles, ',', 3), ',', -1)) AS t4
# FROM name_basics_all
# LIMIT 12;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [('nm0389698', 'tt0970411', 'tt0944947', 'tt0986233', 'tt1240982'),
#  ('nm0269923', 'tt0472160', 'tt0162661', 'tt0120879', 'tt0362192'),
#  ('nm0727778', 'tt1655420', 'tt1139328', 'tt4786824', 'tt6079772'),
#  ('nm6729880', 'tt4154664', 'tt2674426', 'tt6470478', 'tt0944947'),
#  ('nm0853583', 'tt0102797', 'tt0485301', 'tt0462396', 'tt0944947'),
#  ('nm0203801', 'tt12879632', 'tt7366338', 'tt3428912', 'tt0944947'),
#  ('nm8257864', 'tt0944947', 'tt6636246', 'tt5761478', 'tt4276618'),
#  ('nm0571654', 'tt0944947', 'tt0111904', 'tt0166396', 'tt0112178'),
#  ('nm1528121', 'tt3922704', 'tt0053494', 'tt0944947', 'tt1446714'),
#  ('nm0000980', 'tt0203009', 'tt1431181', 'tt1007029', 'tt0217505'),
#  ('nm0649046', 'tt0419706', 'tt0118929', 'tt0203009', 'tt1343727'),
#  ('nm1783582', 'tt15288590', 'tt15249564', 'tt0944947', 'tt9814116')]

# %% [markdown]
# #### Create our own the relationable table, `title_principals_fixed`

# %%
# %%sql
#
# DROP TABLE IF EXISTS title_principals_fixed;
#
# CREATE TABLE title_principals_fixed AS
#
# (WITH temp AS
# (SELECT
#       nconst,
#       SUBSTRING_INDEX(knownForTitles, ',', 1) AS t1,
#       NULLIF(SUBSTRING_INDEX(SUBSTRING_INDEX(knownForTitles, ',', 2), ',', -1),
#         SUBSTRING_INDEX(knownForTitles, ',', 1)) AS t2,
#       NULLIF(SUBSTRING_INDEX(SUBSTRING_INDEX(knownForTitles, ',', 3), ',', -1),
#         SUBSTRING_INDEX(SUBSTRING_INDEX(knownForTitles, ',', 2), ',', -1)) AS t3,
#       NULLIF(SUBSTRING_INDEX(SUBSTRING_INDEX(knownForTitles, ',', 4), ',', -1),
#         SUBSTRING_INDEX(SUBSTRING_INDEX(knownForTitles, ',', 3), ',', -1)) AS t4
# FROM name_basics_all)
#
# SELECT nconst, t1 AS tconst FROM temp
#                                     WHERE t1 IS NOT NULL
# UNION
# SELECT nconst, t2 AS tconst FROM temp
#                                     WHERE t2 IS NOT NULL
# UNION
# SELECT nconst, t3 AS tconst FROM temp
#                                     WHERE t3 IS NOT NULL
# UNION
# SELECT nconst, t4 AS tconst FROM temp
#                                     WHERE t4 IS NOT NULL
# ORDER BY nconst)
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 1317 rows affected.
# []

# %% [markdown]
# #### Have a look at it

# %%
# %%sql
#
# SELECT * FROM title_principals_fixed LIMIT 12;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [('nm0000293', 'tt0120737'),
#  ('nm0000293', 'tt0944947'),
#  ('nm0000293', 'tt1181791'),
#  ('nm0000293', 'tt0167261'),
#  ('nm0000596', 'tt3750872'),
#  ('nm0000596', 'tt0120347'),
#  ('nm0000596', 'tt0104348'),
#  ('nm0000596', 'tt8404614'),
#  ('nm0000980', 'tt0203009'),
#  ('nm0000980', 'tt1007029'),
#  ('nm0000980', 'tt0217505'),
#  ('nm0000980', 'tt1431181')]

# %% [markdown]
# #### This table contains all possible titles (`title_values`).

# %%
# %%sql
#
# DROP TABLE IF EXISTS title_values;
#
# ALTER TABLE title_principals_fixed
# MODIFY COLUMN tconst varchar(32);
#
# CREATE TABLE title_values AS
# SELECT DISTINCT tconst FROM title_principals_fixed;
#
# ALTER TABLE title_values
# ADD PRIMARY KEY (tconst);
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 1317 rows affected.
# 851 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# #### 851 titles in total.

# %%
# %%sql
#
# SELECT count(*) FROM title_values;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [(851,)]

# %% [markdown]
# #### We now set FKs for `title_principals_fixed`

# %%
# %%sql
#
# ALTER TABLE title_principals_fixed
# ADD FOREIGN KEY (nconst) REFERENCES name_basics_all_fixed(nconst);
#
# ALTER TABLE title_principals_fixed
# ADD FOREIGN KEY (tconst) REFERENCES title_values(tconst);
# Out:
#  * mysql+pymysql://root:***@localhost
# 1317 rows affected.
# 1317 rows affected.
# []

# %% [markdown]
# #### See what we have created

# %%
# %sql DESCRIBE title_principals_fixed;
# Out:
#  * mysql+pymysql://root:***@localhost
# 2 rows affected.
# [('nconst', 'varchar(16)', 'NO', 'MUL', '', ''),
#  ('tconst', 'varchar(32)', 'YES', 'MUL', None, '')]

# %%
# %sql DESCRIBE title_values;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [('tconst', 'varchar(32)', 'NO', 'PRI', None, '')]

# %% [markdown]
# #### We did not, actually, create any other tables, so we just do not want to set any foreign key. Primary key is set to be `nconst` (we have seen that it can be used as an identifier from previous `sql` manipulations). Also, variable types and lengths are  set accordingly.

# %% [markdown]
# #### Visualise the final `name_basics_all_fixed` again. All columns are atomic now as required.

# %%
# %sql SELECT * FROM name_basics_all_fixed LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost
# 20 rows affected.
# [('nm0000293', 1959, None, 'Sean ', 'Bean'),
#  ('nm0000596', 1947, None, 'Jonathan ', 'Pryce'),
#  ('nm0000980', 1949, None, 'Jim ', 'Broadbent'),
#  ('nm0001097', 1946, None, 'Charles ', 'Dance'),
#  ('nm0001290', 1957, None, 'Richard ', 'E. Grant'),
#  ('nm0001354', 1953, None, 'Ciarán ', 'Hinds'),
#  ('nm0001671', 1938, 2020, 'Diana ', 'Rigg'),
#  ('nm0002103', 1935, None, 'Julian ', 'Glover'),
#  ('nm0004355', 1957, None, 'Roger ', 'Ashton-Griffiths'),
#  ('nm0004692', 1964, None, 'Mark ', 'Addy'),
#  ('nm0015382', 1967, None, 'Adewale ', 'Akinnuoye-Agbaje'),
#  ('nm0019885', 1953, None, 'Roger ', 'Allam'),
#  ('nm0050520', None, None, 'Peter ', 'Ballance'),
#  ('nm0050959', 1975, None, 'Pedro ', 'Pascal'),
#  ('nm0057965', None, None, 'Clifford ', 'Barry'),
#  ('nm0064155', 1965, None, 'Ian ', 'Beattie'),
#  ('nm0065874', None, None, 'Andy ', 'Beckwith'),
#  ('nm0072855', None, None, 'Paul ', 'Bentley'),
#  ('nm0087432', None, None, 'Nicholas ', 'Blane'),
#  ('nm0103195', 1942, None, 'David ', 'Bradley')]

# %% [markdown]
# - You will need to use SQL to create and load other tables with information from ```name_basics_all``` to enable you to create a view ```name_basics_all_fixed_view``` that recreates the data in ```name_basics_all```. The tables you create should have atomic columns, primary keys and foreign keys, etc.

# %% [markdown]
# #### As discussed in Ed `https://edstem.org/us/courses/32981/discussion/2725932` creating the `name_basics_all_fixed_view`  is just to show that you have not messed up the data in `name_basics_all_fixed`, so it should looks like the original `name_basics_all`. We now use the `name_basics_all_fixed` and other tables to reconstrue the data and compare them with the original data.

# %% [markdown]
# #### Create the view that looks like the original one

# %%
# %%sql
#
# CREATE OR REPLACE VIEW name_basics_all_fixed_view AS
#
# SELECT name_basics_all_fixed.nconst AS nconst,
#        CONCAT(firstName, ' ', lastName) AS primaryName,
#        birthYear,
#        deathYear,
#        primaryProfessions,
#        knownForTitles
#
# FROM name_basics_all_fixed
# LEFT JOIN
# (SELECT nconst, GROUP_CONCAT(professionName SEPARATOR ',') AS primaryProfessions
# FROM name_profession
# GROUP BY nconst) temp1
# ON name_basics_all_fixed.nconst = temp1.nconst
# LEFT JOIN
# (SELECT nconst, GROUP_CONCAT(tconst SEPARATOR ',') AS knownForTitles
# FROM title_principals_fixed
# GROUP BY nconst) temp2
# ON name_basics_all_fixed.nconst = temp2.nconst;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# #### Visualise the results. Since we use `nconst` as the primary key, it is now sorted by it.

# %%
# %sql SELECT * FROM name_basics_all_fixed_view LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost
# 20 rows affected.
# [('nm0000293', 'Sean  Bean', 1959, None, 'actor,producer,animation_department', 'tt0120737,tt0944947,tt1181791,tt0167261'),
#  ('nm0000596', 'Jonathan  Pryce', 1947, None, 'actor,producer,soundtrack', 'tt3750872,tt0120347,tt0104348,tt8404614'),
#  ('nm0000980', 'Jim  Broadbent', 1949, None, 'writer,actor,soundtrack', 'tt0203009,tt1007029,tt0217505,tt1431181'),
#  ('nm0001097', 'Charles  Dance', 1946, None, 'director,writer,actor', 'tt0944947,tt2084970,tt0280707,tt0107362'),
#  ('nm0001290', 'Richard  E. Grant', 1957, None, 'soundtrack,actor,director', 'tt0280707,tt0102070,tt4595882,tt0094336'),
#  ('nm0001354', 'Ciarán  Hinds', 1953, None, 'actor,soundtrack', 'tt12789558,tt1201607,tt1596365,tt1340800'),
#  ('nm0001671', 'Diana  Rigg', 1938, 2020, 'actress,costume_department,soundtrack', 'tt0054518,tt9639470,tt0944947,tt0064757'),
#  ('nm0002103', 'Julian  Glover', 1935, None, 'soundtrack,actor', 'tt0332452,tt0080684,tt0082398,tt0097576'),
#  ('nm0004355', 'Roger  Ashton-Griffiths', 1957, None, 'writer,actor,director', 'tt4575576,tt0944947,tt0217505,tt0088846'),
#  ('nm0004692', 'Mark  Addy', 1964, None, 'actor,soundtrack', 'tt0119164,tt0955308,tt0183790,tt0944947'),
#  ('nm0015382', 'Adewale  Akinnuoye-Agbaje', 1967, None, 'actor,director,writer', 'tt1127881'),
#  ('nm0019885', 'Roger  Allam', 1953, None, 'soundtrack,actor', 'tt1298650,tt0434409,tt0811080,tt1486190'),
#  ('nm0050520', 'Peter  Ballance', None, None, 'miscellaneous,actor', 'tt1985443,tt0323033,tt0408056,tt0944947'),
#  ('nm0050959', 'Pedro  Pascal', 1975, None, 'producer,actor,soundtrack', 'tt0944947,tt4649466,tt7126948,tt8111088'),
#  ('nm0057965', 'Clifford  Barry', None, None, 'actor', 'tt0094535,tt0944947,tt0189192,tt0118363'),
#  ('nm0064155', 'Ian  Beattie', 1965, None, 'writer,director,actor', 'tt0346491,tt2303687,tt0944947,tt2567712'),
#  ('nm0065874', 'Andy  Beckwith', None, None, 'actor', 'tt0208092,tt0944947,tt5691024,tt1355631'),
#  ('nm0072855', 'Paul  Bentley', None, None, 'actor', 'tt0944947,tt0185906,tt8697870,tt1007029'),
#  ('nm0087432', 'Nicholas  Blane', None, None, 'actor', 'tt2343137,tt0373889,tt0944947,tt0443543'),
#  ('nm0103195', 'David  Bradley', 1942, None, 'actor,soundtrack', 'tt0425112,tt0241527,tt1201607,tt1213663')]

# %% [markdown]
# #### To make sure that we did not miss anything, we further check is everything is the same as the original `name_basics_all` table by ordering `name_basics_all` by `nconst`

# %%
# %sql SELECT * FROM name_basics_all ORDER BY nconst LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost
# 20 rows affected.
# [('nm0000293', 'Sean Bean', '1959', None, 'actor,producer,animation_department', 'tt0120737,tt0167261,tt0944947,tt1181791'),
#  ('nm0000596', 'Jonathan Pryce', '1947', None, 'actor,soundtrack,producer', 'tt0104348,tt8404614,tt0120347,tt3750872'),
#  ('nm0000980', 'Jim Broadbent', '1949', None, 'actor,writer,soundtrack', 'tt0203009,tt1431181,tt1007029,tt0217505'),
#  ('nm0001097', 'Charles Dance', '1946', None, 'actor,director,writer', 'tt0944947,tt0107362,tt2084970,tt0280707'),
#  ('nm0001290', 'Richard E. Grant', '1957', None, 'actor,soundtrack,director', 'tt4595882,tt0280707,tt0102070,tt0094336'),
#  ('nm0001354', 'Ciarán Hinds', '1953', None, 'actor,soundtrack', 'tt1340800,tt1596365,tt1201607,tt12789558'),
#  ('nm0001671', 'Diana Rigg', '1938', '2020', 'actress,soundtrack,costume_department', 'tt0054518,tt9639470,tt0064757,tt0944947'),
#  ('nm0002103', 'Julian Glover', '1935', None, 'actor,soundtrack', 'tt0082398,tt0332452,tt0080684,tt0097576'),
#  ('nm0004355', 'Roger Ashton-Griffiths', '1957', None, 'actor,director,writer', 'tt0088846,tt0944947,tt4575576,tt0217505'),
#  ('nm0004692', 'Mark Addy', '1964', None, 'actor,soundtrack', 'tt0944947,tt0955308,tt0119164,tt0183790'),
#  ('nm0015382', 'Adewale Akinnuoye-Agbaje', '1967', None, 'actor,writer,director', 'tt1127881'),
#  ('nm0019885', 'Roger Allam', '1953', None, 'actor,soundtrack', 'tt1486190,tt0811080,tt0434409,tt1298650'),
#  ('nm0050520', 'Peter Ballance', None, None, 'actor,miscellaneous', 'tt0408056,tt0944947,tt0323033,tt1985443'),
#  ('nm0050959', 'Pedro Pascal', '1975', None, 'actor,soundtrack,producer', 'tt4649466,tt7126948,tt0944947,tt8111088'),
#  ('nm0057965', 'Clifford Barry', None, None, 'actor', 'tt0118363,tt0944947,tt0094535,tt0189192'),
#  ('nm0064155', 'Ian Beattie', '1965', None, 'actor,director,writer', 'tt2303687,tt0944947,tt0346491,tt2567712'),
#  ('nm0065874', 'Andy Beckwith', None, None, 'actor', 'tt5691024,tt0208092,tt1355631,tt0944947'),
#  ('nm0072855', 'Paul Bentley', None, None, 'actor', 'tt8697870,tt0944947,tt0185906,tt1007029'),
#  ('nm0087432', 'Nicholas Blane', None, None, 'actor', 'tt2343137,tt0443543,tt0373889,tt0944947'),
#  ('nm0103195', 'David Bradley', '1942', None, 'actor,soundtrack', 'tt1213663,tt0241527,tt1201607,tt0425112')]

# %%
# %sql SELECT count(*) AS numOfRowsOriginal FROM name_basics_all
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [(350,)]

# %%
# %sql SELECT count(*) AS numOfRowsView FROM name_basics_all_fixed_view
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [(350,)]

# %% [markdown]
# #### Indeed the view looks like exactlly the same as the `name_basics_all` table. Also, there is no missing data, i.e., they have same number of rows. (Please note that the order of the concatenated columns do not really matter, especially the `knownForTitles` column. It does not have an intrinsic order at the beginning.)

# %% [markdown]
# #### And we can see that the new `name_basics_all_fixed` satifies all requirements now.

# %%
# %sql SELECT * FROM name_basics_all_fixed LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost
# 20 rows affected.
# [('nm0000293', 1959, None, 'Sean ', 'Bean'),
#  ('nm0000596', 1947, None, 'Jonathan ', 'Pryce'),
#  ('nm0000980', 1949, None, 'Jim ', 'Broadbent'),
#  ('nm0001097', 1946, None, 'Charles ', 'Dance'),
#  ('nm0001290', 1957, None, 'Richard ', 'E. Grant'),
#  ('nm0001354', 1953, None, 'Ciarán ', 'Hinds'),
#  ('nm0001671', 1938, 2020, 'Diana ', 'Rigg'),
#  ('nm0002103', 1935, None, 'Julian ', 'Glover'),
#  ('nm0004355', 1957, None, 'Roger ', 'Ashton-Griffiths'),
#  ('nm0004692', 1964, None, 'Mark ', 'Addy'),
#  ('nm0015382', 1967, None, 'Adewale ', 'Akinnuoye-Agbaje'),
#  ('nm0019885', 1953, None, 'Roger ', 'Allam'),
#  ('nm0050520', None, None, 'Peter ', 'Ballance'),
#  ('nm0050959', 1975, None, 'Pedro ', 'Pascal'),
#  ('nm0057965', None, None, 'Clifford ', 'Barry'),
#  ('nm0064155', 1965, None, 'Ian ', 'Beattie'),
#  ('nm0065874', None, None, 'Andy ', 'Beckwith'),
#  ('nm0072855', None, None, 'Paul ', 'Bentley'),
#  ('nm0087432', None, None, 'Nicholas ', 'Blane'),
#  ('nm0103195', 1942, None, 'David ', 'Bradley')]
