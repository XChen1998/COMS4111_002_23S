# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
# </style>
#
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111: Introduction to Databases<br>
# Spring 2023, Sections 002, V02
# </span>
# </center></b>
# </span><br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# Non-Programming Track, HW2, Part 2<br>
# </span>
# </center></i>

# %% [markdown]
# # Introduction

# %% [markdown]
# ## Environment

# %% [markdown]
# - Test environment.
#
#
# - Set your MySQL user and password below.

# %%
mysql_user = "root"
mysql_pw = "dbuserdbuser"

# %%
# %load_ext sql

# %%
full_url = f"mysql+pymysql://{mysql_user}:{mysql_pw}@localhost"
full_url
# Out:
# 'mysql+pymysql://root:dbuserdbuser@localhost'

# %%
# %sql $full_url

# %%
# %sql select * from db_book.student;
# Out:
#  * mysql+pymysql://root:***@localhost
# 13 rows affected.
# [('00128', 'Zhang', 'Comp. Sci.', Decimal('102')),
#  ('12345', 'Shankar', 'Comp. Sci.', Decimal('32')),
#  ('19991', 'Brandt', 'History', Decimal('80')),
#  ('23121', 'Chavez', 'Finance', Decimal('110')),
#  ('44553', 'Peltier', 'Physics', Decimal('56')),
#  ('45678', 'Levy', 'Physics', Decimal('46')),
#  ('54321', 'Williams', 'Comp. Sci.', Decimal('54')),
#  ('55739', 'Sanchez', 'Music', Decimal('38')),
#  ('70557', 'Snow', 'Physics', Decimal('0')),
#  ('76543', 'Brown', 'Comp. Sci.', Decimal('58')),
#  ('76653', 'Aoi', 'Elec. Eng.', Decimal('60')),
#  ('98765', 'Bourikas', 'Elec. Eng.', Decimal('98')),
#  ('98988', 'Tanaka', 'Biology', Decimal('120'))]

# %% [markdown]
# ## Submission Instructions
#
# - See Ed for instructions.

# %% [markdown]
# # Data and Scheme Cleanup

# %% [markdown]
# ## characters and name_basics_all

# %% [markdown]
# - The task is to "clean up" ```characters``` and produce a table ```charactersFixed```.
#
#
# - The task will require adding missing rows to ```name_basics_all```. There are two row's in ```characters``` that have an ```actorLink``` and ```actorName``` got which there is no matching row in ```name_basics_all```.
#
#
# - ```characters``` has two actors with actorNames ```Barry John O'Connor``` and ```Barry O'Connor``` who are the same actor.
#
#
# - My ```charactersFixed``` has the following columns:
#     - ```characterId``` is a generated primary key. See below for an explanation.
#     - ```characterName```: The value from ```characters```.
#     - ```characterImdbID```: The ```characterLink``` from ```characters``` with ```/character/``` removed.
#     - ```characterLink```: The ```characterLink``` from ```characters```.
#     - ```actorNConst```: ```actorLink``` from ```characters```.
#     - ```actorLink```: A value of the form ```/names/``` followed by the ```actorNConst```.
#     - ```characterImageFull```: The value from ```characters```.
#     - ```characterImageThumb```: The value from ```characters```.
#     - ```kingsguard```: The value from ```characters```.
#     - ```royal```: The value from ```characters```.
#
#
# - The algorithm for generating the ```characterID``` on insert is the following:
#     - The prefix for the ```character``` is either:
#         - The substring of ```characterName``` preceeding the first ' '.
#         - The ```characterName``` is there is no ' '.
#     - If there are ```N``` rows in the table, the number after the prefix is ```N+1```.
#     - Implementing this is tricky. Your first attempt might rely on ```auto-increment```, but this does not work. You may also be tempted to count rows, but that does not work. A hint is that you will need to use a trigger and some other table/data that you create.
#
#
# - The directory with this notebook containers data from my version of ```charactersFixed```.
#
#
# - The cells below load the data to allow you to examine. In your SQL table, ```NaN``` will be ```NULL```.

# %%
import pandas as pd

# %%
characters_df = pd.read_csv('./charactersFixed.csv')

# %%
characters_df
# Out:
#     characterId        characterName characterImdbID         characterLink  \
# 0        Addam1       Addam Marbrand       ch0305333  /character/ch0305333
# 1        Aegon2      Aegon Targaryen             NaN                   NaN
# 2        Aeron3        Aeron Greyjoy       ch0540081  /character/ch0540081
# 3        Aerys4   Aerys II Targaryen       ch0541362  /character/ch0541362
# 4         Akho5                 Akho       ch0544520  /character/ch0544520
# ..          ...                  ...             ...                   ...
# 384    Young385            Young Nan       ch0305018  /character/ch0305018
# 385    Young386            Young Ned       ch0154681  /character/ch0154681
# 386    Young387      Young Ned Stark       ch0154681  /character/ch0154681
# 387    Young388  Young Rodrik Cassel       ch0171391  /character/ch0171391
# 388  Zanrush389              Zanrush       ch0540870  /character/ch0540870
#
#     actorNconst         actorLink  \
# 0     nm0389698  /names/nm0389698
# 1           NaN               NaN
# 2     nm0269923  /names/nm0269923
# 3     nm0727778  /names/nm0727778
# 4     nm6729880  /names/nm6729880
# ..          ...               ...
# 384   nm1519719  /names/nm1519719
# 385   nm7075019  /names/nm7075019
# 386   nm7509185  /names/nm7509185
# 387   nm7509186  /names/nm7509186
# 388   nm0503319  /names/nm0503319
#
#                                     characterImageFull  \
# 0                                                  NaN
# 1                                                  NaN
# 2    https://images-na.ssl-images-amazon.com/images...
# 3    https://images-na.ssl-images-amazon.com/images...
# 4    https://images-na.ssl-images-amazon.com/images...
# ..                                                 ...
# 384                                                NaN
# 385                                                NaN
# 386                                                NaN
# 387                                                NaN
# 388  https://images-na.ssl-images-amazon.com/images...
#
#                                    characterImageThumb  kingsguard  royal
# 0                                                  NaN         NaN    NaN
# 1                                                  NaN         NaN    1.0
# 2    https://images-na.ssl-images-amazon.com/images...         NaN    NaN
# 3    https://images-na.ssl-images-amazon.com/images...         NaN    1.0
# 4    https://images-na.ssl-images-amazon.com/images...         NaN    NaN
# ..                                                 ...         ...    ...
# 384                                                NaN         NaN    NaN
# 385                                                NaN         NaN    NaN
# 386                                                NaN         NaN    NaN
# 387                                                NaN         NaN    NaN
# 388  https://images-na.ssl-images-amazon.com/images...         NaN    NaN
#
# [389 rows x 10 columns]

# %%
# Use my schema
# %sql USE s23_w4111_hw2_xc2605
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# #### Have a look at the current results

# %%
# %sql SELECT * FROM characters LIMIT 12;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [('/character/ch0305333/', 'Addam Marbrand', 'nm0389698', 'B.J. Hogg', None, None, None, None),
#  (None, 'Aegon Targaryen', None, None, None, None, None, 1),
#  ('/character/ch0540081/', 'Aeron Greyjoy', 'nm0269923', 'Michael Feast', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzI5MDg0ZDAtN2Y2ZC00MzU1LTgyYjQtNTBjYjEzODczZDVhXkEyXkFqcGdeQXVyNTg0Nzg4NTE@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzI5MDg0ZDAtN2Y2ZC00MzU1LTgyYjQtNTBjYjEzODczZDVhXkEyXkFqcGdeQXVyNTg0Nzg4NTE@._V1._SX100_SY140_.jpg', None, None),
#  ('/character/ch0541362/', 'Aerys II Targaryen', 'nm0727778', 'David Rintoul', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWQzOWViN2ItNDZhOS00MmZlLTkxZTYtZDg5NGUwMGRmYWZjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWQzOWViN2ItNDZhOS00MmZlLTkxZTYtZDg5NGUwMGRmYWZjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, 1),
#  ('/character/ch0544520/', 'Akho', 'nm6729880', 'Chuku Modu', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGE4ZDZmOGUtNGE4Ny00Y2VmLThiOGItMjk3Y2U0ZDY3OWQxXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGE4ZDZmOGUtNGE4Ny00Y2VmLThiOGItMjk3Y2U0ZDY3OWQxXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('/character/ch0246938/', 'Alliser Thorne', 'nm0853583', 'Owen Teale', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAxMjExMjA3M15BMl5BanBnXkFtZTcwMjI1ODg5NA@@._V1_SY1000_CR0,0,666,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAxMjExMjA3M15BMl5BanBnXkFtZTcwMjI1ODg5NA@@._V1._SX100_SY140_.jpg', None, None),
#  ('/character/ch0305012/', 'Alton Lannister', 'nm0203801', 'Karl Davies', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU0NTU1NTAzOF5BMl5BanBnXkFtZTcwNzA2NDk4OA@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU0NTU1NTAzOF5BMl5BanBnXkFtZTcwNzA2NDk4OA@@._V1._SX100_SY140_.jpg', None, None),
#  ('/character/ch0576836/', 'Alys Karstark', 'nm8257864', 'Megan Parkinson', None, None, None, None),
#  ('/character/ch0305002/', 'Amory Lorch', 'nm0571654', 'Fintan McKeown', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTVmY2M2YmUtY2JkYS00NjIyLWFhYTAtNTNlZmI4ODdiNmE5XkEyXkFqcGdeQXVyMjg2MTMyNTM@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTVmY2M2YmUtY2JkYS00NjIyLWFhYTAtNTNlZmI4ODdiNmE5XkEyXkFqcGdeQXVyMjg2MTMyNTM@._V1._SX100_SY140_.jpg', None, None),
#  ('/character/ch0316930/', 'Anguy', 'nm1528121', 'Philip McGinley', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNmRhY2M4YmItNjc2Yi00ZDc0LWE5NmUtNGE5OWE0YTQ2YjY3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNmRhY2M4YmItNjc2Yi00ZDc0LWE5NmUtNGE5OWE0YTQ2YjY3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('/character/ch0578265/', 'Archmaester Marwyn', 'nm0000980', 'Jim Broadbent', None, None, None, None),
#  ('/character/ch0507107/', 'Areo Hotah', 'nm0649046', 'Deobia Oparei', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNWFkNTAwNzctOGQ2ZS00OTMyLWE3NDYtOGUwM2E1MzVlYjI0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNWFkNTAwNzctOGQ2ZS00OTMyLWE3NDYtOGUwM2E1MzVlYjI0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None)]

# %% [markdown]
# #### create a new table

# %%
# %%sql
#
# DROP TABLE IF EXISTS charactersFixed;
#
# CREATE TABLE charactersFixed
# (
#     characterID varchar(32)     not null,
#     characterLink text,
#     characterName text,
#     actorLink text,
#     actorName text,
#     characterImageFull text,
#     characterImageThumb text,
#     kingsguard tinyint(1) DEFAULT NULL,
#     royal tinyint(1) DEFAULT NULL,
#     CONSTRAINT charactersFixed_pk
#         PRIMARY KEY (characterID)
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# DROP FUNCTION IF EXISTS compute_next_ID;
#
# CREATE FUNCTION compute_next_ID(characterName varchar(64)) RETURNS varchar(32)
#     READS SQL DATA
# BEGIN
#
#     DECLARE prefix varchar(32);
#     DECLARE count int;
#     DECLARE result varchar(32);
#
#     SET prefix = SUBSTRING_INDEX(characterName, ' ', 1);
#
#     SET count = (SELECT COUNT(*) FROM s23_w4111_hw2_xc2605.charactersFixed) + 1;
#
#     SET result = concat(prefix, count);
#
#     return result;
#
# end;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# DROP TRIGGER IF EXISTS COMPUTE_ID;
#
# CREATE TRIGGER COMPUTE_ID
#     BEFORE INSERT
#     ON s23_w4111_hw2_xc2605.charactersFixed
#     FOR EACH ROW
# BEGIN
#     SET new.characterID = compute_next_ID(new.characterName);
# end;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql

# DROP PROCEDURE IF EXISTS getFixed;
# CREATE PROCEDURE getFixed()
# BEGIN
# DECLARE n INT DEFAULT 0;
# DECLARE i INT DEFAULT 0;
# SELECT COUNT(*) FROM characters INTO n;
# SET i=0;
# WHILE i<n DO 
#   INSERT INTO charactersFixed(characterLink, characterName, actorLink, actorName, characterImageFull, characterImageThumb, kingsguard, royal) 
#   SELECT characterLink, characterName, actorLink, actorName, characterImageFull, characterImageThumb, kingsguard, royal FROM characters LIMIT i,1;
#   SET i = i + 1;
# END WHILE;
# End;

# %%
# %sql CALL getFixed();

# %%
# %%sql
# INSERT INTO charactersFixed (characterLink, characterName,
#                              actorLink, actorName, characterImageFull,
#                              characterImageThumb, kingsguard, royal)
# SELECT characterLink, characterName,
#        actorLink, actorName, characterImageFull,
#        characterImageThumb, kingsguard, royal
# FROM characters
# Out:
#  * mysql+pymysql://root:***@localhost
# 389 rows affected.
# []

# %%
# %sql SELECT * FROM charactersFixed
# Out:
#  * mysql+pymysql://root:***@localhost
# 389 rows affected.
# [('Addam1', '/character/ch0305333/', 'Addam Marbrand', 'nm0389698', 'B.J. Hogg', None, None, None, None),
#  ('Aegon2', None, 'Aegon Targaryen', None, None, None, None, None, 1),
#  ('Aeron3', '/character/ch0540081/', 'Aeron Greyjoy', 'nm0269923', 'Michael Feast', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzI5MDg0ZDAtN2Y2ZC00MzU1LTgyYjQtNTBjYjEzODczZDVhXkEyXkFqcGdeQXVyNTg0Nzg4NTE@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzI5MDg0ZDAtN2Y2ZC00MzU1LTgyYjQtNTBjYjEzODczZDVhXkEyXkFqcGdeQXVyNTg0Nzg4NTE@._V1._SX100_SY140_.jpg', None, None),
#  ('Aerys4', '/character/ch0541362/', 'Aerys II Targaryen', 'nm0727778', 'David Rintoul', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWQzOWViN2ItNDZhOS00MmZlLTkxZTYtZDg5NGUwMGRmYWZjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWQzOWViN2ItNDZhOS00MmZlLTkxZTYtZDg5NGUwMGRmYWZjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, 1),
#  ('Akho5', '/character/ch0544520/', 'Akho', 'nm6729880', 'Chuku Modu', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGE4ZDZmOGUtNGE4Ny00Y2VmLThiOGItMjk3Y2U0ZDY3OWQxXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGE4ZDZmOGUtNGE4Ny00Y2VmLThiOGItMjk3Y2U0ZDY3OWQxXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Alliser6', '/character/ch0246938/', 'Alliser Thorne', 'nm0853583', 'Owen Teale', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAxMjExMjA3M15BMl5BanBnXkFtZTcwMjI1ODg5NA@@._V1_SY1000_CR0,0,666,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAxMjExMjA3M15BMl5BanBnXkFtZTcwMjI1ODg5NA@@._V1._SX100_SY140_.jpg', None, None),
#  ('Alton7', '/character/ch0305012/', 'Alton Lannister', 'nm0203801', 'Karl Davies', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU0NTU1NTAzOF5BMl5BanBnXkFtZTcwNzA2NDk4OA@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU0NTU1NTAzOF5BMl5BanBnXkFtZTcwNzA2NDk4OA@@._V1._SX100_SY140_.jpg', None, None),
#  ('Alys8', '/character/ch0576836/', 'Alys Karstark', 'nm8257864', 'Megan Parkinson', None, None, None, None),
#  ('Amory9', '/character/ch0305002/', 'Amory Lorch', 'nm0571654', 'Fintan McKeown', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTVmY2M2YmUtY2JkYS00NjIyLWFhYTAtNTNlZmI4ODdiNmE5XkEyXkFqcGdeQXVyMjg2MTMyNTM@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTVmY2M2YmUtY2JkYS00NjIyLWFhYTAtNTNlZmI4ODdiNmE5XkEyXkFqcGdeQXVyMjg2MTMyNTM@._V1._SX100_SY140_.jpg', None, None),
#  ('Anguy10', '/character/ch0316930/', 'Anguy', 'nm1528121', 'Philip McGinley', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNmRhY2M4YmItNjc2Yi00ZDc0LWE5NmUtNGE5OWE0YTQ2YjY3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNmRhY2M4YmItNjc2Yi00ZDc0LWE5NmUtNGE5OWE0YTQ2YjY3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Archmaester11', '/character/ch0578265/', 'Archmaester Marwyn', 'nm0000980', 'Jim Broadbent', None, None, None, None),
#  ('Areo12', '/character/ch0507107/', 'Areo Hotah', 'nm0649046', 'Deobia Oparei', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNWFkNTAwNzctOGQ2ZS00OTMyLWE3NDYtOGUwM2E1MzVlYjI0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNWFkNTAwNzctOGQ2ZS00OTMyLWE3NDYtOGUwM2E1MzVlYjI0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Armeca13', '/character/ch0305014/', 'Armeca', 'nm1783582', 'Sahara Knite', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZmQyMGVlMDctYWFhMi00YzMyLTlkZDgtOWNmZTY3NmZkYzZlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZmQyMGVlMDctYWFhMi00YzMyLTlkZDgtOWNmZTY3NmZkYzZlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Arthur14', '/character/ch0305326/', 'Arthur', 'nm8127149', 'Nathanael Saleh', None, None, None, None),
#  ('Arthur15', '/character/ch0540097/', 'Arthur Dayne', 'nm1074361', 'Luke Roberts', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODczZDUxYmQtMzk1MC00ZTUwLTk1MjAtZDJlODViMWFhOGU5XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODczZDUxYmQtMzk1MC00ZTUwLTk1MjAtZDJlODViMWFhOGU5XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', 1, None),
#  ('Arya16', '/character/ch0158604/', 'Arya Stark', 'nm3586035', 'Maisie Williams', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk5MTYwNDc0OF5BMl5BanBnXkFtZTcwOTg2NDg1Nw@@._V1_SY1000_CR0,0,665,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk5MTYwNDc0OF5BMl5BanBnXkFtZTcwOTg2NDg1Nw@@._V1._SX100_SY140_.jpg', None, None),
#  ('Baby17', '/character/ch0547881/', 'Baby Sam', None, None, None, None, None, None),
#  ('Balon18', '/character/ch0292152/', 'Balon Greyjoy', 'nm0538869', 'Patrick Malahide', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTUxNjkwODczN15BMl5BanBnXkFtZTcwODMwNTgzNw@@._V1_SY1000_CR0,0,637,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTUxNjkwODczN15BMl5BanBnXkFtZTcwODMwNTgzNw@@._V1._SX100_SY140_.jpg', None, None),
#  ('Baratheon19', '/character/ch0350989/', 'Baratheon Guard', 'nm4207240', 'Phil Barnhill', None, None, None, None),
#  ('Barristan20', '/character/ch0241346/', 'Barristan Selmy', 'nm0568400', 'Ian McElhinney', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTUy
1XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Dothraki55', '/character/ch0542918/', 'Dothraki Bloodrider #1', 'nm6088160', 'Diogo Sales', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ2Mzk1MzczMl5BMl5BanBnXkFtZTgwNDQyODAxODE@._V1_SY1000_CR0,0,1502,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ2Mzk1MzczMl5BMl5BanBnXkFtZTgwNDQyODAxODE@._V1._SX100_SY140_.jpg', None, None),
#  ('Dothraki56', '/character/ch0542918/', 'Dothraki Bloodrider #2', 'nm2999602', 'Junade Khan', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ2Mzk1MzczMl5BMl5BanBnXkFtZTgwNDQyODAxODE@._V1_SY1000_CR0,0,1502,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ2Mzk1MzczMl5BMl5BanBnXkFtZTgwNDQyODAxODE@._V1._SX100_SY140_.jpg', None, None),
#  ('Drennan57', '/character/ch0305030/', 'Drennan', 'nm2231505', 'David Coakley', None, None, None, None),
#  ('Drogon58', None, 'Drogon', None, None, None, None, None, None),
#  ('Drowned59', '/character/ch0411375/', 'Drowned Priest', 'nm0752638', 'Jonathan Ryan', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGEwMjRhYzgtYjY1YS00MjhlLTllYjYtNWQzOGQxOTE3ZDczXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGEwMjRhYzgtYjY1YS00MjhlLTllYjYtNWQzOGQxOTE3ZDczXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Eddard60', '/character/ch0154681/', 'Eddard Stark', 'nm0000293', 'Sean Bean', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODcwMjg0MDQ5MF5BMl5BanBnXkFtZTcwMTk2NDk4OQ@@._V1_SY1000_CR0,0,827,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODcwMjg0MDQ5MF5BMl5BanBnXkFtZTcwMTk2NDk4OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Eddison61', '/character/ch0305008/', 'Eddison Tollett', 'nm0174005', 'Ben Crompton', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY1MjQ4ODAwNV5BMl5BanBnXkFtZTcwMTc5NDk4OQ@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY1MjQ4ODAwNV5BMl5BanBnXkFtZTcwMTc5NDk4OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Edmure62', '/character/ch0316931/', 'Edmure Tully', 'nm0580014', 'Tobias Menzies', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYjEzNThlMmQtMDgzYi00MTQ5LTllMzQtNDZjY2JiMTVhNmNkXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYjEzNThlMmQtMDgzYi00MTQ5LTllMzQtNDZjY2JiMTVhNmNkXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Elia64', None, 'Elia Martell', None, None, None, None, None, 1),
#  ('Ellaria63', '/character/ch0309687/', 'Ellaria Sand', 'nm0890055', 'Indira Varma', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNWQ0ZDE5NDUtNDVmZi00ZTI5LTkyOTgtNDhiNjMwZjY3ZjgwXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNWQ0ZDE5NDUtNDVmZi00ZTI5LTkyOTgtNDhiNjMwZjY3ZjgwXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Eon65', '/character/ch0305321/', 'Eon Hunter', 'nm4473207', 'Barrington Cullen', None, None, None, None),
#  ('Euron66', '/character/ch0518715/', 'Euron Greyjoy', 'nm1561982', 'Pilou Asbæk', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzg1MTJhMjMtMmY4Yy00NTU2LTliZWUtNjM4YzAxY2M3ZDBkXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzg1MTJhMjMtMmY4Yy00NTU2LTliZWUtNjM4YzAxY2M3ZDBkXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Faceless67', '/character/ch0259179/', 'Faceless Man', 'nm2406775', 'Cedric Henderson', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjI4ODYxODI0MF5BMl5BanBnXkFtZTgwMDk4NDY0NTE@._V1_SY1000_CR0,0,665,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjI4ODYxODI0MF5BMl5BanBnXkFtZTgwMDk4NDY0NTE@._V1_UX214_CR0,0,214,317_AL_.jpg', None, None),
#  ('Farlen68', '/character/ch0305027/', 'Farlen', 'nm0050520', 'Peter Ballance', None, None, None, None),
#  ('Gared69', '/character/ch0171395/', 'Gared', 'nm0443825', 'Dermot Keaney', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNGYxZjljZTctZjIxYy00YmUwLTk3MDgtZWIyZjhkNDgwYTZiXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNGYxZjljZTctZjIxYy00YmUwLTk3MDgtZWIyZjhkNDgwYTZiXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Gatins70', '/character/ch0523969/', 'Gatins', 'nm2307468', 'Ricky Champ', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzIwZmJkNDktZWMwMC00ZGNlLWJkNWYtN2ZmOWEzNDFiNWMyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_SX1777_CR0,0,1777,999_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzIwZmJkNDktZWMwMC00ZGNlLWJkNWYtN2ZmOWEzNDFiNWMyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Gendry71', '/character/ch0300040/', 'Gendry', 'nm1478079', 'Joe Dempsie', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTcxNzYwMTk4MV5BMl5BanBnXkFtZTcwNDg1ODg4OQ@@._V1_SY1000_CR0,0,846,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTcxNzYwMTk4MV5BMl5BanBnXkFtZTcwNDg1ODg4OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Gerold72', '/character/ch0540530/', 'Gerold Hightower', 'nm6793798', 'Eddie Eyre', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODc3OTIzYmEtYjk2Yy00NTgwLTk4OWMtMjlmMmJmNDE5OGU2XkEyXkFqcGdeQXVyNjU5MTM2ODI@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODc3OTIzYmEtYjk2Yy00NTgwLTk4OWMtMjlmMmJmNDE5OGU2XkEyXkFqcGdeQXVyNjU5MTM2ODI@._V1._SX100_SY140_.jpg', None, None),
#  ('Ghost73', None, 'Ghost', None, None, None, None, None, None),
#  ('Gilly74', '/character/ch0306819/', 'Gilly', 'nm2356940', 'Hannah Murray', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTYzOTQxMTA3MF5BMl5BanBnXkFtZTcwODM5NDk4OQ@@._V1_SY1000_CR0,0,760,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTYzOTQxMTA3MF5BMl5BanBnXkFtZTcwODM5NDk4OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Goldcloak75', '/character/ch0305037/', 'Goldcloak', 'nm3354768', 'Alan Paris', None, None, None, None),
#  ('Goldcloak76', '/character/ch0305037/', 'Goldcloak', 'nm0130538', 'Sam Callis', None, None, None, None),
#  ('Goldcloak77', '/character/ch0305037/', 'Goldcloak #1', 'nm2089809', 'Nikovich Sammut', None, None, None, None),
#  ('Goldcloak78', '/character/ch0305037/', 'Goldcloak #2', 'nm4440118', 'Seamus Kelly', None, None, None, None),
#  ('Grand79', '/character/ch0232836/', 'Grand Maester Pycelle', 'nm0002103', 'Julian Glover', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjEyNDA4MzQ3MF5BMl5BanBnXkFtZTcwNTM3ODg4OQ@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjEyNDA4MzQ3MF5BMl5BanBnXkFtZTcwNTM3ODg4OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Great80', '/character/ch0525536/', 'Great Master #1', None, None, None, None, None, None),
#  ('Great81', '/character/ch0525536/', 'Great Master #2', None, None, None, None, None, None),
#  ('Great82', '/character/ch0525536/', 'Great Master #3', 'nm0798872', 'Peter Silverleaf', None, None, None, None),
#  ('Great83', '/character/ch0525536/', 'Great Master #4', 'nm7318132', 'Davor Jozinovic', None, None, None, None),
#  ('Great84', '/character/ch0525536/', 'Great Master #5', 'nm3005802', 'Ivan Peric', None, None, None, None),
#  ('Great85', '/character/ch0525536/', 'Great Master #6', 'nm7318134', 'Hadi Kermani', None, None, None, None),
#  ('Great86', '/character/ch0525536/', 'Great Master #7', 'nm7318135', 'Tonci Banov', None, None, None, None),
#  ('Greatjon87', '/character/ch0305010/', 'Greatjon Umber', 'nm0544139', 'Clive Mantle', 'https://images-na.ssl-images-amazon.com/images/M/MV5BN2VjMTM4OTItMDUxMi00N2NiLThhMWMtNGNhMDQ4OGJhOWU0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BN2VjMTM4OTItMDUxMi00N2NiLThhMWMtNGNhMDQ4OGJhOWU0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('
 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjIzMzU1NjM1MF5BMl5BanBnXkFtZTcwMzIxODg4OQ@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjIzMzU1NjM1MF5BMl5BanBnXkFtZTcwMzIxODg4OQ@@._V1._SX100_SY140_.jpg', 1, None),
#  ('Janos115', '/character/ch0300651/', 'Janos Slynt', 'nm0141582', 'Dominic Carter', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNGUwMzllZGEtZjdkZi00NTgwLTgxY2UtODFhZjZlZDNmN2ZkXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNGUwMzllZGEtZjdkZi00NTgwLTgxY2UtODFhZjZlZDNmN2ZkXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_SY100_SX100_AL_.jpg', None, None),
#  ("Jaqen's117", '/character/ch0259179/', "Jaqen's Disguise", 'nm0641433', "Patrick O'Kane", None, None, None, None),
#  ('Jaqen116', '/character/ch0259179/', "Jaqen H'ghar", 'nm0937239', 'Tom Wlaschiha', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA1MjI5MzYwNzNeQTJeQWpwZ15BbWU3MDkxNDcxOTk@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA1MjI5MzYwNzNeQTJeQWpwZ15BbWU3MDkxNDcxOTk@._V1._SX100_SY140_.jpg', None, None),
#  ('Jaremy118', '/character/ch0305324/', 'Jaremy Rykker', 'nm4475335', "Jeffrey O'Brien", 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjg4YjRmMDYtZjcyMS00YjM3LTg4OWQtZTg2MDFiZTJkZDIwXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjg4YjRmMDYtZjcyMS00YjM3LTg4OWQtZTg2MDFiZTJkZDIwXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Jeor119', '/character/ch0251492/', 'Jeor Mormont', 'nm0181920', 'James Cosmo', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODAwODYyNzk0NV5BMl5BanBnXkFtZTcwNDI2NDk4OQ@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODAwODYyNzk0NV5BMl5BanBnXkFtZTcwNDI2NDk4OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Jhiqui120', '/character/ch0305044/', 'Jhiqui', 'nm4424689', 'Sarita Piotrowski', None, None, None, None),
#  ('Joffrey121', '/character/ch0156278/', 'Joffrey Baratheon', 'nm0322416', 'Jack Gleeson', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk1NDg5MTAwMl5BMl5BanBnXkFtZTcwOTIwODg4OQ@@._V1_SY1000_CR0,0,818,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk1NDg5MTAwMl5BMl5BanBnXkFtZTcwOTIwODg4OQ@@._V1._SX100_SY140_.jpg', None, 1),
#  ('Jojen122', '/character/ch0316921/', 'Jojen Reed', 'nm1032473', 'Thomas Brodie-Sangster', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg0OTU4MTk4M15BMl5BanBnXkFtZTcwMTE4MTE5OQ@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg0OTU4MTk4M15BMl5BanBnXkFtZTcwMTE4MTE5OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Jon123', '/character/ch0251737/', 'Jon Arryn', 'nm0822062', 'John Standing', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYmJiMzVjYzEtODA2ZC00NTkwLWI1ZDEtNDUxM2Y1NzcxZjU0XkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYmJiMzVjYzEtODA2ZC00NTkwLWI1ZDEtNDUxM2Y1NzcxZjU0XkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1._SX100_SY140_.jpg', None, None),
#  ('Jon124', '/character/ch0155777/', 'Jon Snow', 'nm3229685', 'Kit Harington', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTkwMjUxMDk2OV5BMl5BanBnXkFtZTcwMzg3MTg4OQ@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTkwMjUxMDk2OV5BMl5BanBnXkFtZTcwMzg3MTg4OQ@@._V1._SX100_SY140_.jpg', None, 1),
#  ('Jonos125', '/character/ch0305332/', 'Jonos Bracken', 'nm0639569', "Gerry O'Brien", None, None, None, None),
#  ('Jorah126', '/character/ch0158221/', 'Jorah Mormont', 'nm0322513', 'Iain Glen', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTkz
._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYTFkMWRiMDItN2Q2Ny00N2VlLWIxMzYtZDMwODkwNDE4ZTYyXkEyXkFqcGdeQXVyMTk0NzA0Njg@._V1._SX100_SY140_.jpg', None, None),
#  ("King's141", '/character/ch0348391/', "King's Landing Rioter #1", 'nm1168404', 'Reg Wayment', None, None, None, None),
#  ("King's142", '/character/ch0348391/', "King's Landing Rioter #2", 'nm0432837', 'Marko Juraga', None, None, None, None),
#  ("King's143", '/character/ch0348391/', "King's Landing Rioter #3", 'nm5037688', 'Rea Separovic', None, None, None, None),
#  ('King137', '/character/ch0156278/', 'King Joffrey Baratheon Dwarf', 'nm0341739', 'Raymond Griffiths', None, None, None, None),
#  ('King138', '/character/ch0246253/', 'King Renly Baratheon Dwarf', 'nm2482781', 'Dean Whatton', None, None, None, None),
#  ('King139', '/character/ch0158596/', 'King Robb Stark Dwarf', 'nm3338062', 'George Appleby', None, None, None, None),
#  ('King140', '/character/ch0250897/', 'King Stannis Baratheon Dwarf', 'nm3453345', 'Maxwell Laird', None, None, None, None),
#  ('Kinvara144', '/character/ch0540065/', 'Kinvara', 'nm0119804', 'Ania Bukstein', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZGNkYWZlZmYtM2Y4Yi00YmJjLTk1OTktNDc0YmMxODY5ZTI2XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZGNkYWZlZmYtM2Y4Yi00YmJjLTk1OTktNDc0YmMxODY5ZTI2XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Kitty145', '/character/ch0576869/', 'Kitty Frey', 'nm8314450', 'Lucy Hayes', None, None, None, None),
#  ('Knight146', '/character/ch0305317/', 'Knight of House Frey', 'nm3122423', 'Patrick Ryan', None, None, None, None),
#  ('Knight147', '/character/ch0305322/', 'Knight of House Lynderly', 'nm0734304', 'Paddy Rocks', None, None, None, None),
#  ('Kovarro148', '/character/ch0304969/', 'Kovarro', 'nm0170799', 'Steven Cole', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZjRmMzgyY2QtMzNmYy00NmRhLWIxNzItOGEwOWU2MzA5YjUwXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZjRmMzgyY2QtMzNmYy00NmRhLWIxNzItOGEwOWU2MzA5YjUwXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Kraznys149', '/character/ch0339503/', 'Kraznys mo Nakloz', 'nm0383835', 'Dan Hildebrand', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWIzZGY0NWUtMmM1OC00NDYzLTkxMjYtM2I1MGM5MTkzODMwXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWIzZGY0NWUtMmM1OC00NDYzLTkxMjYtM2I1MGM5MTkzODMwXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Kurleket150', '/character/ch0305315/', 'Kurleket', 'nm4450657', 'Kevin Keenan', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMmY3NWI0YTItNWFkZi00MTVlLWIyNDQtN2MwYjY0ZjhhOTdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMmY3NWI0YTItNWFkZi00MTVlLWIyNDQtN2MwYjY0ZjhhOTdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Lady151', None, 'Lady', None, None, None, None, None, None),
#  ('Lady152', '/character/ch0541190/', 'Lady Crane', 'nm0204583', 'Essie Davis', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZTUyOTFlNjgtYzJjYS00MDY5LWJhMDQtYTJiZThjOTlmNTg3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZTUyOTFlNjgtYzJjYS00MDY5LWJhMDQtYTJiZThjOTlmNTg3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Lancel153', '/character/ch0376927/', 'Lancel Lannister', 'nm1638294', 'Eugene Simon', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjI0MTQ5MzEzNV5BMl5BanBnXkFtZTgwNTQ4MDA2NTE@._V1_SY1000_CR0,0,1503,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjI0MTQ5MzEzNV5BMl5BanBnXkFtZTgwNTQ4MDA2NTE@._V1._SX100_SY140_.jpg', None, None),
#  ('Lannister154', '/character/ch0305308/', 'Lannister Captain', 'nm0174449', 'Aiden Condron', None, None, None, None),
#  ('Lannister155', '/character/ch0305308/', 'Lannister Captain', 'nm0481924', 'Richard Laing', None, None, None, None),
#  ('Lannister156', '/character/ch0305047/', 'Lannister Guardsman', 'nm1406364', 'Conor Delaney', None, None, None, None),
#  ('Lannister157', '/character/ch0379228/', 'Lannister Messenger', 'nm4492930', 'Simon Stewart', None, None, None, None),
#  ('Lannister158', '/character/ch0379230/', 'Lannister Scout', 'nm3292422', 'Chris Gallagher', None, None, None, None),
#  ('Lead159', '/character/ch0539716/', 'Lead Dornish Guard', 'nm5908524', 'Christian Vit', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTYwMzM5ODM3OV5BMl5BanBnXkFtZTgwMjU1ODg2NTE@._V1_SX865_CR0,0,865,999_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTYwMzM5ODM3OV5BMl5BanBnXkFtZTgwMjU1ODg2NTE@._V1._SX100_SY140_.jpg', None, None),
#  ('Leaf160', '/character/ch0467999/', 'Leaf', None, None, 'https://images-na.ssl-images-amazon.com/images/M/MV5BYTJjNGJhYmYtNGViMy00NTg3LWI0M2YtNmM3OGI3NzA3MGVjXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYTJjNGJhYmYtNGViMy00NTg3LWI0M2YtNmM3OGI3NzA3MGVjXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Lem161', '/character/ch0542106/', 'Lem Lemoncloak', 'nm1778512', 'Jóhannes Haukur Jóhannesson', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZWYxOGUwODAtZmY0MS00OTFkLWI0YTUtZTkxNjI1ZjE1YmJhXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZWYxOGUwODAtZmY0MS00OTFkLWI0YTUtZTkxNjI1ZjE1YmJhXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Leo162', '/character/ch0305040/', 'Leo Lefford', 'nm0564516', 'Vinnie McCabe', None, None, None, None),
#  ('Lhara163', '/character/ch0476558/', 'Lhara', 'nm3330066', 'Sarine Sofair', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTBjZDY4M2YtOWU1ZC00NTA2LWI4ODItYWZjYjlhMWY5NDhmL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTBjZDY4M2YtOWU1ZC00NTA2LWI4ODItYWZjYjlhMWY5NDhmL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Little164', '/character/ch0305326/', 'Little Bird', 'nm6537691', 'Samuel Paul Small', None, None, None, None),
#  ('Little165', '/character/ch0305326/', 'Little Bird', 'nm4475204', 'Tristan Mercieca', None, None, None, None),
#  ('Little166', '/character/ch0305326/', 'Little Bird #3', 'nm8127150', 'Michael Nevin', None, None, None, None),
#  ('Little167', '/character/ch0305326/', 'Little Bird #4', 'nm8127151', 'Jesse Magee', None, None, None, None),
#  ('Little168', '/character/ch0305326/', 'Little Bird #5', 'nm8133415', 'Iona Clarke', None, None, None, None),
#  ('Little169', '/character/ch0305326/', 'Little Bird #6', 'nm8127152', 'Lucy Gallagher', None, None, None, None),
#  ('Little170', '/character/ch0305326/', 'Little Bird #7', 'nm6462692', 'Fionn Kernan', None, None, None, None),
#  ('Loboda171', '/character/ch0511931/', 'Loboda', 'nm1707712', 'Zachary Baharov', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMDU5NzIxYzQtNDExMi00YTljLThiNjItMWIxNDEwZTJhNjZkXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMDU5NzIxYzQtNDExMi00YTljLThiNjItMWIxNDEwZTJhNjZkXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
# ...
#  ('The333', '/character/ch0512154/', 'The Night King', None, None, 'https://images-na.ssl-images-amazon.com/images/M/MV5BY2ZjNmYyMjAtNGUwYi00N2JmLWEyMTYtMDM5YmM2MWFhMWFiXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BY2ZjNmYyMjAtNGUwYi00N2JmLWEyMTYtMDM5YmM2MWFhMWFiXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1._SX100_SY140_.jpg', None, None),
#  ('The334', '/character/ch0305033/', 'The Tickler', 'nm1677757', 'Anthony Morris', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTRiZjdkNTctMzM3ZC00NDJjLWI1MjctNTdjZjFlYjNiOTMxXkEyXkFqcGdeQXVyMjg2MTMyNTM@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTRiZjdkNTctMzM3ZC00NDJjLWI1MjctNTdjZjFlYjNiOTMxXkEyXkFqcGdeQXVyMjg2MTMyNTM@._V1._SX100_SY140_.jpg', None, None),
#  ('The335', '/character/ch0508054/', 'The Waif', 'nm3849670', 'Faye Marsay', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMzlkNTU5NTYtNmY5OS00NTY2LTk2YWItODU0OTc0MTA5NDQ1XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMzlkNTU5NTYtNmY5OS00NTY2LTk2YWItODU0OTc0MTA5NDQ1XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Thenn336', '/character/ch0400416/', 'Thenn Warg', 'nm1395532', 'Joseph Gatt', None, None, None, None),
#  ('Theon337', '/character/ch0158526/', 'Theon Greyjoy', 'nm0654295', 'Alfie Allen', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTM3ODUyOTY3N15BMl5BanBnXkFtZTcwNjI4MTg4OQ@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTM3ODUyOTY3N15BMl5BanBnXkFtZTcwNjI4MTg4OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Thin338', '/character/ch0540863/', 'Thin Man', 'nm0534062', 'Oengus MacNamara', None, None, None, None),
#  ('Thoros339', '/character/ch0316927/', 'Thoros of Myr', 'nm0443373', 'Paul Kaye', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTYwNzc0MDUzNF5BMl5BanBnXkFtZTcwMDc1NzE5OQ@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTYwNzc0MDUzNF5BMl5BanBnXkFtZTcwMDc1NzE5OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Three-Eyed340', '/character/ch0414457/', 'Three-Eyed Raven', None, None, 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGI4NGRiNTUtM2ZlYy00ZjhlLWJlYWItMjgzNWIzYWQwZWY0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGI4NGRiNTUtM2ZlYy00ZjhlLWJlYWItMjgzNWIzYWQwZWY0XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Timett341', '/character/ch0305004/', 'Timett', 'nm4385245', 'Tobias Winter', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTM5MjU1NzA1NF5BMl5BanBnXkFtZTcwOTA2Nzk1NQ@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTM5MjU1NzA1NF5BMl5BanBnXkFtZTcwOTA2Nzk1NQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Tobho342', '/character/ch0305039/', 'Tobho Mott', 'nm0928408', 'Andrew Wilde', None, None, None, None),
#  ('Todder343', '/character/ch0509452/', 'Todder', 'nm3727276', "Will O'Connell", None, None, None, None),
#  ('Tomard344', '/character/ch0305325/', 'Tomard', 'nm4475303', 'Phil Dixon', None, None, None, None),
#  ('Tommen345', '/character/ch0256424/', 'Tommen Baratheon', None, None, 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTY1YWUxM2QtZjhmZC00ZmQ2LThkM2YtNTk2MmQ5OTk3NGMyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTY1YWUxM2QtZjhmZC00ZmQ2LThkM2YtNTk2MmQ5OTk3NGMyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, 1),
#  ('Tormund346', '/character/ch0316925/', 'Tormund Giantsbane', 'nm1970465', 'Kristofer Hivju', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc1OTU3NjUzNF5BMl5BanBnXkFtZTcwNDE0NzE5OQ@@._V1_SY1000_CR0,0,717,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc1OTU3NjUzNF5BMl5BanBnXkFtZTcwNDE0NzE5OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Trystane347', '/character/ch0506400/', 'Trystane Martell', 'nm4514519', 'Toby Sebastian', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODkzNjY0NTA0MV5BMl5BanBnXkFtZTgwNjc1NDE3NTE@._V1_.jpg', 'https://m.media-amazon.com/images/M/MV5BODkzNjY0NTA0MV5BMl5BanBnXkFtZTgwNjc1NDE3NTE@._V1_SX100_CR0,0,100,100_AL_.jpg', None, None),
#  ('Tycho348', '/character/ch0468190/', 'Tycho Nestoris', 'nm0309693', 'Mark Gatiss', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTFjYWJjZTEtM2Y1Zi00YzE0LTkzOTItZGZkNzM2YjBiNjg5XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTFjYWJjZTEtM2Y1Zi00YzE0LTkzOTItZGZkNzM2YjBiNjg5XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Tyene349', '/character/ch0468075/', 'Tyene Sand', 'nm3065809', 'Rosabell Laurenti Sellers', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNDY5NzBiMTQtYzhmMS00Y2FmLTkzYzYtYzM2ODBjNGZlNGNiXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNDY5NzBiMTQtYzhmMS00Y2FmLTkzYzYtYzM2ODBjNGZlNGNiXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Tyrion350', '/character/ch0146096/', 'Tyrion Lannister', 'nm0227759', 'Peter Dinklage', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA2MDAwOTI0OV5BMl5BanBnXkFtZTcwNjA3NDg1Nw@@._V1_SX1500_CR0,0,1500,999_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA2MDAwOTI0OV5BMl5BanBnXkFtZTcwNjA3NDg1Nw@@._V1._SX100_SY140_.jpg', None, None),
#  ('Tywin351', '/character/ch0242185/', 'Tywin Lannister', 'nm0001097', 'Charles Dance', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTA4ODMxMzE1OV5BMl5BanBnXkFtZTcwMTM0ODg4OQ@@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTA4ODMxMzE1OV5BMl5BanBnXkFtZTcwMTM0ODg4OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Vala352', '/character/ch0539344/', 'Vala', 'nm5159884', 'Meena Rayann', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYzdiYzllYjMtMGJmNC00NWIwLWIwMzEtOTM1Mjk4ZTkxZDM1XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYzdiYzllYjMtMGJmNC00NWIwLWIwMzEtOTM1Mjk4ZTkxZDM1XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Vardis353', '/character/ch0294458/', 'Vardis Egen', 'nm1788152', 'Brendan McCormack', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMzg1Y2NiYTYtNDY0Yi00OGMwLWJjZjktZDVlNDE1Y2M3MTMzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMzg1Y2NiYTYtNDY0Yi00OGMwLWJjZjktZDVlNDE1Y2M3MTMzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Varly354', '/character/ch0379226/', 'Varly', 'nm1378721', 'Graham Charles', None, None, None, None),
#  ('Viserion355', None, 'Viserion', None, None, None, None, None, None),
#  ('Viserys356', '/character/ch0155775/', 'Viserys Targaryen', 'nm0516003', 'Harry Lloyd', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTgwNzIxMTU1OV5BMl5BanBnXkFtZTcwNzI2ODg5NA@@._V1_SY1000_CR0,0,1503,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTgwNzIxMTU1OV5BMl5BanBnXkFtZTcwNzI2ODg5NA@@._V1._SX100_SY140_.jpg', None, 1),
#  ('Walda357', '/character/ch0506401/', 'Walda Bolton', 'nm3531913', 'Elizabeth Webster', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTZiNWE2YTYtZDA2Ny00ZmUwLTk4ZWUtZjFkM2JkYjFiNjE3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTZiNWE2YTYtZDA2Ny00ZmUwLTk4ZWUtZjFkM2JkYjFiNjE3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Walder358', '/character/ch0305328/', 'Walder Frey', 'nm0103195', 'David Bradley', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYzU0YzZjMTktZDA2Ni00YTRhLWFkZTgtOTQ4Yjg2MmQ2OGUzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYzU0YzZjMTktZDA2Ni00YTRhLWFkZTgtOTQ4Yjg2MmQ2OGUzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Wallen359', None, 'Wallen', None, "Barry O'Connor", None, None, None, None),
#  ('Warlock360', '/character/ch0539881/', 'Warlock', 'nm5390029', 'Lottie Steer', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMzE0NjExMGMtYjJlOC00MWI4LTg5MTgtYTIzZTgxZjc2NDAyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMzE0NjExMGMtYjJlOC00MWI4LTg5MTgtYTIzZTgxZjc2NDAyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Waymar361', '/character/ch0171390/', 'Waymar Royce', 'nm3209935', 'Rob Ostlere', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYzE1Y2EwN2QtMzMzZS00MDZkLTg4ZjItN2NkNGNkYjAzZGVlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BYzE1Y2EwN2QtMzMzZS00MDZkLTg4ZjItN2NkNGNkYjAzZGVlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Wedding362', '/character/ch0506962/', 'Wedding Band', 'nm1460176', 'Sigur Rós', None, None, None, None),
#  ('White363', '/character/ch0304921/', 'White Walker', 'nm1613839', 'Ian Whyte', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYzNDMyZWUtMDVlMy00OGQxLWFkZTctOWMxZDk1MDA5MmQzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYzNDMyZWUtMDVlMy00OGQxLWFkZTctOWMxZDk1MDA5MmQzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('White364', '/character/ch0304921/', 'White Walker', 'nm1368643', 'Ross Mullan', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYzNDMyZWUtMDVlMy00OGQxLWFkZTctOWMxZDk1MDA5MmQzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYzNDMyZWUtMDVlMy00OGQxLWFkZTctOWMxZDk1MDA5MmQzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('White365', '/character/ch0304921/', 'White Walker', 'nm0516385', 'Tim Loane', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYzNDMyZWUtMDVlMy00OGQxLWFkZTctOWMxZDk1MDA5MmQzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYzNDMyZWUtMDVlMy00OGQxLWFkZTctOWMxZDk1MDA5MmQzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('White366', '/character/ch0304921/', 'White Walker #2', 'nm1872855', 'Spencer Wilding', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYzNDMyZWUtMDVlMy00OGQxLWFkZTctOWMxZDk1MDA5MmQzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYzNDMyZWUtMDVlMy00OGQxLWFkZTctOWMxZDk1MDA5MmQzXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Wight367', '/character/ch0305043/', 'Wight Wildling Girl', 'nm4422708', 'Claire Wright', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTg0OTdiOTYtNjBlYS00ZjI1LWEzMTAtODExOWRhNDZhMWNhXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTg0OTdiOTYtNjBlYS00ZjI1LWEzMTAtODExOWRhNDZhMWNhXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Wildling368', '/character/ch0348391/', 'Wildling Rioter', 'nm8199963', 'Michael Patrick', None, None, None, None),
#  ('Will369', '/character/ch0171394/', 'Will', 'nm0916037', 'Bronson Webb', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA0NjU2MjIzNF5BMl5BanBnXkFtZTgwNzEyODI1MDI@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA0NjU2MjIzNF5BMl5BanBnXkFtZTgwNzEyODI1MDI@._V1_SY100_CR16,0,100,100_AL_.jpg', None, None),
#  ('Willem370', '/character/ch0395356/', 'Willem Lannister', 'nm5624523', 'Timothy Gibbons', None, None, None, None),
#  ('Willis371', '/character/ch0305315/', 'Willis Wode', 'nm4416560', 'Ryan McKenna', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMmY3NWI0YTItNWFkZi00MTVlLWIyNDQtN2MwYjY0ZjhhOTdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMmY3NWI0YTItNWFkZi00MTVlLWIyNDQtN2MwYjY0ZjhhOTdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Wine372', '/character/ch0305323/', 'Wine Merchant', 'nm0523047', 'Simon Lowe', None, None, None, None),
#  ('Winterfell373', '/character/ch0306456/', 'Winterfell Shepherd', 'nm0214343', 'Donagh Deeney', None, None, None, None),
#  ('Wun374', '/character/ch0524621/', 'Wun Wun', 'nm1613839', 'Ian Whyte', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTFjMTczNTQtNzE5MC00ZTI1LWI0ZGMtMTA4NGU2ZGQ5ZjRkXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTFjMTczNTQtNzE5MC00ZTI1LWI0ZGMtMTA4NGU2ZGQ5ZjRkXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1._SX100_SY140_.jpg', None, None),
#  ('Wyllis375', '/character/ch0238584/', 'Wyllis', 'nm4744043', 'Sam Coleman', None, None, None, None),
#  ('Xaro376', '/character/ch0303950/', 'Xaro Xhoan Daxos', 'nm1996829', 'Nonso Anozie', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU3NTA5NDA3NF5BMl5BanBnXkFtZTcwNzY2NDg1Nw@@._V1_SY1000_CR0,0,666,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU3NTA5NDA3NF5BMl5BanBnXkFtZTcwNzY2NDg1Nw@@._V1._SX100_SY140_.jpg', None, None),
#  ('Yara377', '/character/ch0300217/', 'Yara Greyjoy', 'nm2247629', 'Gemma Whelan', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc2NzU5ODk0MV5BMl5BanBnXkFtZTcwMzEyNDY2OQ@@._V1_SY1000_CR0,0,1503,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc2NzU5ODk0MV5BMl5BanBnXkFtZTcwMzEyNDY2OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Yezzan378', '/character/ch0470706/', 'Yezzan zo Qaggaz', 'nm0162281', 'Enzo Cilenti', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZDgyOTFhMzktNWE5MS00YTY3LTk0YTYtMjkyMjFkODIxOTJiXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZDgyOTFhMzktNWE5MS00YTY3LTk0YTYtMjkyMjFkODIxOTJiXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Ygritte379', '/character/ch0304492/', 'Ygritte', 'nm3310211', 'Rose Leslie', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg0NDA1Njk3Nl5BMl5BanBnXkFtZTcwOTQ2NDk4OQ@@._V1_SY1000_CR0,0,724,1000_AL_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg0NDA1Njk3Nl5BMl5BanBnXkFtZTcwOTQ2NDk4OQ@@._V1._SX100_SY140_.jpg', None, None),
#  ('Yohn380', '/character/ch0524546/', 'Yohn Royce', 'nm0889338', 'Rupert Vansittart', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZjgwNDc4NGQtMmQyMS00YjMyLWFhZWUtZmM0MjRkYmNmNGExXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BZjgwNDc4NGQtMmQyMS00YjMyLWFhZWUtZmM0MjRkYmNmNGExXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Yoren381', '/character/ch0251493/', 'Yoren', 'nm0535837', 'Francis Magee', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTZjZWMwZWItYTdlNi00N2RmLWFlYjQtZTZlYTIxYTRkMWJlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTZjZWMwZWItYTdlNi00N2RmLWFlYjQtZTZlYTIxYTRkMWJlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None),
#  ('Young382', '/character/ch0153996/', 'Young Benjen Stark', 'nm5502295', 'Matteo Elezi', None, None, None, None),
#  ('Young383', '/character/ch0159526/', 'Young Cersei Lannister', 'nm5309709', 'Nell Williams', None, None, None, None),
#  ('Young384', '/character/ch0543804/', 'Young Lyanna Stark', 'nm8108764', 'Cordelia Hill', None, None, None, None),
#  ('Young385', '/character/ch0305018/', 'Young Nan', 'nm1519719', 'Annette Tierney', None, None, None, None),
#  ('Young386', '/character/ch0154681/', 'Young Ned', 'nm7075019', 'Robert Aramayo', None, None, None, None),
#  ('Young387', '/character/ch0154681/', 'Young Ned Stark', 'nm7509185', 'Sebastian Croft', None, None, None, None),
#  ('Young388', '/character/ch0171391/', 'Young Rodrik Cassel', 'nm7509186', 'Fergus Leathem', None, None, None, None),
#  ('Zanrush389', '/character/ch0540870/', 'Zanrush', 'nm0503319', 'Gerald Lepkowski', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTJjYzk1MGMtNjE3Mi00NjE2LTkzMWUtNGRjODVlY2JmMmI5XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTJjYzk1MGMtNjE3Mi00NjE2LTkzMWUtNGRjODVlY2JmMmI5XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', None, None)]

# %% [markdown]
# - Your answer below should show all of your SQL statements, including DDL, for creating and loading ```charactersFixed``` as well as changes to ```name_basics_all```.
#
#
# - You can use the data in the CSV file to test your work. Show at least one test.

# %%
# %%sql
#
# /* SQL statements in this cell. You may use multiple cells. */
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
#
# /* SQL test to show result. */
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# ## name_basics_all

# %% [markdown]
# - The column ```primaryProfessions``` is multi-valued and non-atomic. This violates good relational design principle.
#
#
# - Create a new table ```name_basics_all_fixed``` which does not have the column ```primaryProfessions```.
#
#
# - You will need to use SQL to create and load other tables with information from ```name_basics_all``` to enable you to create a view ```name_basics_all_fixed_view``` that recreates the data in ```name_basics_all```. The tables you create should have atomic columns, primary keys and foreign keys, etc.

# %%
# %%sql
#
# /* Use this cell and others to create tables, load data, etc. */
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
#
# /* Write a query that uses your view to reproduce name_basics_all */
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []
